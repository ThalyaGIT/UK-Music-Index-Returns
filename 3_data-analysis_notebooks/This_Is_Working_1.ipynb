# %% [markdown]
# <a href="https://colab.research.google.com/github/ThalyaGIT/UK-Music-Index-Returns/blob/main/3_data-analysis_notebooks/This_Is_Working_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title
# Import packages
import pandas as pd
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from tabulate import tabulate
from scipy import stats
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy.stats.mstats import winsorize
from scipy.stats import zscore

print("Packages have been imported...")
# Out:
# Packages have been imported...

# %%
# @title
# Open CSV into dataframe
url_1_day = 'https://raw.githubusercontent.com/ThalyaGIT/UK-Music-Index-Returns/main/0-data-gold/data_1_days.csv'
url_3_day = 'https://raw.githubusercontent.com/ThalyaGIT/UK-Music-Index-Returns/main/0-data-gold/data_3_days.csv'
url_5_day = 'https://raw.githubusercontent.com/ThalyaGIT/UK-Music-Index-Returns/main/0-data-gold/data_5_days.csv'
url_10_day = 'https://raw.githubusercontent.com/ThalyaGIT/UK-Music-Index-Returns/main/0-data-gold/data_10_days.csv'
url_20_day = 'https://raw.githubusercontent.com/ThalyaGIT/UK-Music-Index-Returns/main/0-data-gold/data_20_days.csv'

df_1_day = pd.read_csv(url_1_day)
df_3_day = pd.read_csv(url_3_day)
df_5_day = pd.read_csv(url_5_day)
df_10_day = pd.read_csv(url_10_day)
df_20_day = pd.read_csv(url_20_day)


# Open CSV into dataframe with TED
url_1_day_TED = 'https://raw.githubusercontent.com/ThalyaGIT/UK-Music-Index-Returns/main/0-data-gold/data_1_days_TED.csv'
url_3_day_TED = 'https://raw.githubusercontent.com/ThalyaGIT/UK-Music-Index-Returns/main/0-data-gold/data_3_days_TED.csv'
url_5_day_TED = 'https://raw.githubusercontent.com/ThalyaGIT/UK-Music-Index-Returns/main/0-data-gold/data_5_days_TED.csv'
url_10_day_TED = 'https://raw.githubusercontent.com/ThalyaGIT/UK-Music-Index-Returns/main/0-data-gold/data_10_days_TED.csv'
url_20_day_TED = 'https://raw.githubusercontent.com/ThalyaGIT/UK-Music-Index-Returns/main/0-data-gold/data_20_days_TED.csv'

df_1_day_TED = pd.read_csv(url_1_day_TED)
df_3_day_TED = pd.read_csv(url_3_day_TED)
df_5_day_TED = pd.read_csv(url_5_day_TED)
df_10_day_TED = pd.read_csv(url_10_day_TED)
df_20_day_TED = pd.read_csv(url_20_day_TED)

print("data has been loaded....")
# Out:
# data has been loaded....

# %% [markdown]
# # **Main Regression Results**

# %%
# @title
## Main Script

# Initialize an empty list to store results
results = []

indices = ['FTSE100', 'FTSE250', 'FTSESmallCap']
days_list = [5]
#days_list = [1, 3, 5, 10]

for days in days_list:
    result_row = [days]  # Start the row with the number of days
    for index in indices:
        df = globals()[f'df_{days}_day']  # Dynamically access each DataFrame

        # Ensure 'Date' column is in datetime format
        df['Date'] = pd.to_datetime(df['Date'])

        # Extract the month from the 'Date' column
        df['Month'] = df['Date'].dt.month

        # Create dummy variables for the months
        month_dummies = pd.get_dummies(df['Month'], prefix='Month', drop_first=True)

        # Convert boolean dummy variables to integers
        month_dummies = month_dummies.astype(int)

        # Define the dependent variable
        y = df[f'% {index} Change']

        # Define the independent variables
        X = df[['Change in SWAV',
                'ADS_Change',
                'EPU_Change',
                f'Previous % {index} Change',
                '% MSCI Change',
                'Vix Close',
                'Rolling_Avg_Change_in_DCC']]

        # Add the month dummies to the independent variables
        X = pd.concat([X, month_dummies], axis=1)

        # Convert all columns to numeric, coercing errors to NaN
        X = X.apply(pd.to_numeric, errors='coerce')
        y = pd.to_numeric(y, errors='coerce')

        # Drop rows with any NaN values
        X = X.dropna()
        y = y.loc[X.index]  # Ensure 'y' aligns with 'X' after dropping NaNs

        # Ensure that both X and y are aligned and are purely numeric
        if X.shape[0] > 0 and y.shape[0] > 0:  # Proceed only if there's valid data
            # Add a constant term to the model
            X = sm.add_constant(X)

            # vif_data = pd.DataFrame()
            # vif_data['feature'] = X.columns
            # vif_data['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
            # print(vif_data)

            # Fit the model
            model = sm.OLS(y, X).fit()

            # Extract the coefficient and p-value for 'Change in SWAV'
            coef = round(model.params['Change in SWAV'], 2)
            p_value = round(model.pvalues['Change in SWAV'], 5)

            # Store the coefficient and p-value as a tuple
            result_row.append((coef, p_value))
        else:
            result_row.append((None, None))  # Store None for both if no valid data

    # Append the result row for this combination of days
    results.append(result_row)

# Define column names dynamically, ensuring "Days" is the first column
columns = ['Days']
for index in indices:
    columns.extend([f'{index} Coef'])  # Ensure you have columns for coefficients only

# Convert the results list to a DataFrame, extracting only the coefficients
results_df = pd.DataFrame([[row[0]] + [r[0] if isinstance(r, tuple) else None for r in row[1:]] for row in results], columns=columns)

# Define a function to apply the styling based on significance
def color_rows(row, original_results):
    colors = []
    for i in range(1, len(row)):  # Skip Days, then iterate through Coefs
        # Safely access the original tuple
        item = original_results[row.name][i]
        if isinstance(item, tuple):
            coef, p_value = item
            if coef is not None and p_value < 0.1:  # Only color if p-value < 0.1 (significant)
                if coef > 0:
                    colors.append('background-color: green')
                elif coef < 0:
                    colors.append('background-color: red')
                else:
                    colors.append('')
            else:
                colors.append('')  # No color for non-significant or None
        else:
            colors.append('')  # No color if item is not a tuple
    return [''] * 1 + colors  # No coloring for Days

# Apply the function to each row of the DataFrame, passing the original results
styled_df = results_df.style.apply(color_rows, axis=1, original_results=results)

print("Multicollinearity checks done")
# Display the styled DataFrame
styled_df
# Out:
# Multicollinearity checks done
# <style type="text/css">
# #T_2e297_row0_col1, #T_2e297_row0_col2 {
#   background-color: red;
# }
# </style>
# <table id="T_2e297" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e297_level0_col0" class="col_heading level0 col0" >Days</th>
#       <th id="T_2e297_level0_col1" class="col_heading level0 col1" >FTSE100 Coef</th>
#       <th id="T_2e297_level0_col2" class="col_heading level0 col2" >FTSE250 Coef</th>
#       <th id="T_2e297_level0_col3" class="col_heading level0 col3" >FTSESmallCap Coef</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e297_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2e297_row0_col0" class="data row0 col0" >5</td>
#       <td id="T_2e297_row0_col1" class="data row0 col1" >-7.100000</td>
#       <td id="T_2e297_row0_col2" class="data row0 col2" >-3.410000</td>
#       <td id="T_2e297_row0_col3" class="data row0 col3" >0.450000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # **Distribution of Change in SWAV**
#
# The bar chart reveals significant monthly variations in "Change in SWAV," especially during the festive season at year-end. These fluctuations likely distort the data, so I will see how the regression looks like when I  remove festive periods. Doing so will clarify the true relationship between SWAV changes and index returns.

# %%
# @title
# Ensure 'Date' column is in datetime format
df_5_day['Date'] = pd.to_datetime(df_5_day['Date'])

# Extract the month from the 'Date' column
df_5_day['Month'] = df_5_day['Date'].dt.month

# Calculate the average 'Change in SWAV' by month
monthly_avg = df_5_day.groupby('Month')['Change in SWAV'].mean()

# Plot the average 'Change in SWAV' by month
plt.figure(figsize=(10, 6))
monthly_avg.plot(kind='bar', color='skyblue')
plt.title('Average Change in SWAV by Month')
plt.xlabel('Month')
plt.ylabel('Average Change in SWAV')
plt.xticks(ticks=range(12), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.show()

# %% [markdown]
# # **Remove Festive Data**

# %%
# @title
## Main Script

# Initialize an empty list to store results
results = []

indices = ['FTSE100', 'FTSE250', 'FTSESmallCap']
days_list = [5]
#days_list = [1, 3, 5, 10]

for days in days_list:
    result_row = [days]  # Start the row with the number of days
    for index in indices:
        df = globals()[f'df_{days}_day']  # Dynamically access each DataFrame

        # Ensure 'Date' column is in datetime format
        df['Date'] = pd.to_datetime(df['Date'])

        # Extract the month from the 'Date' column
        df['Month'] = df['Date'].dt.month

        df = df[df['festive'] == 0]

        # Create dummy variables for the months
        month_dummies = pd.get_dummies(df['Month'], prefix='Month', drop_first=True)

        # Convert boolean dummy variables to integers
        month_dummies = month_dummies.astype(int)

        # Define the dependent variable
        y = df[f'% {index} Change']

        # Define the independent variables
        X = df[['Change in SWAV',
                'ADS_Change',
                'EPU_Change',
                f'Previous % {index} Change',
                '% MSCI Change',
                'Vix Close',
                'Rolling_Avg_Change_in_DCC']]

        # Add the month dummies to the independent variables
        X = pd.concat([X, month_dummies], axis=1)

        # Convert all columns to numeric, coercing errors to NaN
        X = X.apply(pd.to_numeric, errors='coerce')
        y = pd.to_numeric(y, errors='coerce')

        # Drop rows with any NaN values
        X = X.dropna()
        y = y.loc[X.index]  # Ensure 'y' aligns with 'X' after dropping NaNs

        # Ensure that both X and y are aligned and are purely numeric
        if X.shape[0] > 0 and y.shape[0] > 0:  # Proceed only if there's valid data
            # Add a constant term to the model
            X = sm.add_constant(X)

            # vif_data = pd.DataFrame()
            # vif_data['feature'] = X.columns
            # vif_data['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
            # print(vif_data)

            # Fit the model
            model = sm.OLS(y, X).fit()

            # Extract the coefficient and p-value for 'Change in SWAV'
            coef = round(model.params['Change in SWAV'], 2)
            p_value = round(model.pvalues['Change in SWAV'], 5)

            # Store the coefficient and p-value as a tuple
            result_row.append((coef, p_value))
        else:
            result_row.append((None, None))  # Store None for both if no valid data

    # Append the result row for this combination of days
    results.append(result_row)

# Define column names dynamically, ensuring "Days" is the first column
columns = ['Days']
for index in indices:
    columns.extend([f'{index} Coef'])  # Ensure you have columns for coefficients only

# Convert the results list to a DataFrame, extracting only the coefficients
results_df = pd.DataFrame([[row[0]] + [r[0] if isinstance(r, tuple) else None for r in row[1:]] for row in results], columns=columns)

# Define a function to apply the styling based on significance
def color_rows(row, original_results):
    colors = []
    for i in range(1, len(row)):  # Skip Days, then iterate through Coefs
        # Safely access the original tuple
        item = original_results[row.name][i]
        if isinstance(item, tuple):
            coef, p_value = item
            if coef is not None and p_value < 0.1:  # Only color if p-value < 0.1 (significant)
                if coef > 0:
                    colors.append('background-color: green')
                elif coef < 0:
                    colors.append('background-color: red')
                else:
                    colors.append('')
            else:
                colors.append('')  # No color for non-significant or None
        else:
            colors.append('')  # No color if item is not a tuple
    return [''] * 1 + colors  # No coloring for Days

# Apply the function to each row of the DataFrame, passing the original results
styled_df = results_df.style.apply(color_rows, axis=1, original_results=results)

print("Multicollinearity checks done")
# Display the styled DataFrame
styled_df
# Out:
# Multicollinearity checks done
# <style type="text/css">
# #T_546b6_row0_col1 {
#   background-color: red;
# }
# #T_546b6_row0_col3 {
#   background-color: green;
# }
# </style>
# <table id="T_546b6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_546b6_level0_col0" class="col_heading level0 col0" >Days</th>
#       <th id="T_546b6_level0_col1" class="col_heading level0 col1" >FTSE100 Coef</th>
#       <th id="T_546b6_level0_col2" class="col_heading level0 col2" >FTSE250 Coef</th>
#       <th id="T_546b6_level0_col3" class="col_heading level0 col3" >FTSESmallCap Coef</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_546b6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_546b6_row0_col0" class="data row0 col0" >5</td>
#       <td id="T_546b6_row0_col1" class="data row0 col1" >-6.410000</td>
#       <td id="T_546b6_row0_col2" class="data row0 col2" >0.620000</td>
#       <td id="T_546b6_row0_col3" class="data row0 col3" >5.510000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # **New Control fo Covid Stringency**

# %%
# @title
## Main Script

# Initialize an empty list to store results
results = []

indices = ['FTSE100', 'FTSE250', 'FTSESmallCap']
days_list = [5]
#days_list = [1, 3, 5, 10]

for days in days_list:
    result_row = [days]  # Start the row with the number of days
    for index in indices:
        df = globals()[f'df_{days}_day']  # Dynamically access each DataFrame

        # Ensure 'Date' column is in datetime format
        df['Date'] = pd.to_datetime(df['Date'])

        # Extract the month from the 'Date' column
        df['Month'] = df['Date'].dt.month

        df = df[df['festive'] == 0].copy()

        df['Covid_Stringency*SWAV'] = df['Change in SWAV']*df['Stringency_Change']

        # Create dummy variables for the months
        month_dummies = pd.get_dummies(df['Month'], prefix='Month', drop_first=True)

        # Convert boolean dummy variables to integers
        month_dummies = month_dummies.astype(int)

        # Define the dependent variable
        y = df[f'% {index} Change']

        # Define the independent variables
        X = df[['Change in SWAV',
                'ADS_Change',
                'EPU_Change',
                f'Previous % {index} Change',
                '% MSCI Change',
                'Vix Close',
                'Rolling_Avg_Change_in_DCC',
                'Stringency_Change',
                'Covid_Stringency*SWAV'
                ]]

        # Add the month dummies to the independent variables
        X = pd.concat([X, month_dummies], axis=1)

        # Convert all columns to numeric, coercing errors to NaN
        X = X.apply(pd.to_numeric, errors='coerce')
        y = pd.to_numeric(y, errors='coerce')

        # Drop rows with any NaN values
        X = X.dropna()
        y = y.loc[X.index]  # Ensure 'y' aligns with 'X' after dropping NaNs

        # Ensure that both X and y are aligned and are purely numeric
        if X.shape[0] > 0 and y.shape[0] > 0:  # Proceed only if there's valid data
            # Add a constant term to the model
            X = sm.add_constant(X)

            # vif_data = pd.DataFrame()
            # vif_data['feature'] = X.columns
            # vif_data['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
            # print(vif_data)

            # Fit the model
            model = sm.OLS(y, X).fit()

            # Extract the coefficient and p-value for 'Change in SWAV'
            coef = round(model.params['Change in SWAV'], 2)
            p_value = round(model.pvalues['Change in SWAV'], 5)

            # Store the coefficient and p-value as a tuple
            result_row.append((coef, p_value))
        else:
            result_row.append((None, None))  # Store None for both if no valid data

    # Append the result row for this combination of days
    results.append(result_row)

# Define column names dynamically, ensuring "Days" is the first column
columns = ['Days']
for index in indices:
    columns.extend([f'{index} Coef'])  # Ensure you have columns for coefficients only

# Convert the results list to a DataFrame, extracting only the coefficients
results_df = pd.DataFrame([[row[0]] + [r[0] if isinstance(r, tuple) else None for r in row[1:]] for row in results], columns=columns)

# Define a function to apply the styling based on significance
def color_rows(row, original_results):
    colors = []
    for i in range(1, len(row)):  # Skip Days, then iterate through Coefs
        # Safely access the original tuple
        item = original_results[row.name][i]
        if isinstance(item, tuple):
            coef, p_value = item
            if coef is not None and p_value < 0.1:  # Only color if p-value < 0.1 (significant)
                if coef > 0:
                    colors.append('background-color: green')
                elif coef < 0:
                    colors.append('background-color: red')
                else:
                    colors.append('')
            else:
                colors.append('')  # No color for non-significant or None
        else:
            colors.append('')  # No color if item is not a tuple
    return [''] * 1 + colors  # No coloring for Days

# Apply the function to each row of the DataFrame, passing the original results
styled_df = results_df.style.apply(color_rows, axis=1, original_results=results)

print("Multicollinearity checks done")
# Display the styled DataFrame
styled_df
# Out:
# Multicollinearity checks done
# <style type="text/css">
# #T_13dee_row0_col1 {
#   background-color: red;
# }
# #T_13dee_row0_col3 {
#   background-color: green;
# }
# </style>
# <table id="T_13dee" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13dee_level0_col0" class="col_heading level0 col0" >Days</th>
#       <th id="T_13dee_level0_col1" class="col_heading level0 col1" >FTSE100 Coef</th>
#       <th id="T_13dee_level0_col2" class="col_heading level0 col2" >FTSE250 Coef</th>
#       <th id="T_13dee_level0_col3" class="col_heading level0 col3" >FTSESmallCap Coef</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13dee_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_13dee_row0_col0" class="data row0 col0" >5</td>
#       <td id="T_13dee_row0_col1" class="data row0 col1" >-6.160000</td>
#       <td id="T_13dee_row0_col2" class="data row0 col2" >0.600000</td>
#       <td id="T_13dee_row0_col3" class="data row0 col3" >5.310000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # **Distribution of TED Spread**

# %%
# @title
df_5_day_TED['Date'] = pd.to_datetime(df['Date'])


# Plotting the TED spread across the selected years
plt.figure(figsize=(10, 6))
plt.plot(df_5_day_TED['Date'], df_5_day_TED['TED'], label='TED Spread', color='blue')
plt.title('TED Spread from 2017 to 2022')
plt.xlabel('Date')
plt.ylabel('TED Spread')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# # **Regression with TED interaction**

# %%
# @title
## Main Script

# Initialize an empty list to store results
results = []

indices = ['FTSE100','FTSE250', 'FTSESmallCap']
#days_list = [1, 3, 5, 10]
days_list = [5]

for days in days_list:
    result_row = [days]  # Start the row with the number of days
    for index in indices:
        df = globals()[f'df_{days}_day_TED']  # Dynamically access each DataFrame

        # Ensure 'Date' column is in datetime format
        df['Date'] = pd.to_datetime(df['Date'])

        # Extract the month from the 'Date' column
        df['Month'] = df['Date'].dt.month

        df = df[df['festive'] == 0]

        # Calculate the Z-scores for TED values
        df['TED_z'] = zscore(df['TED'])

        # Define the threshold for extreme Z-scores (e.g., Z-scores > 2 or < -2)
        z_threshold = 2

        # Filter the DataFrame to include only rows where TED Z-score is within the normal range
        df_filtered = df[(df['TED_z'] > -z_threshold) & (df['TED_z'] < z_threshold)]

        # Create dummy variables for the months
        month_dummies = pd.get_dummies(df['Month'], prefix='Month', drop_first=True)

        # Convert boolean dummy variables to integers
        month_dummies = month_dummies.astype(int)

        df['TED_z*SWAV'] = df['Change in SWAV']*df['TED_z']
        df['Covid_Stringency*SWAV'] = df['Change in SWAV']*df['Stringency_Change']

        # Define the dependent variable
        y = df[f'% {index} Change']

        # Define the independent variables
        X = df[[  'Change in SWAV',
                  'ADS_Change',
                  'EPU_Change',
                   f'Previous % {index} Change',
                  '% MSCI Change',
                  'Vix Close',
                  'Rolling_Avg_Change_in_DCC',
                  'Stringency_Change',
                  'Covid_Stringency*SWAV',
                  'TED_z*SWAV',
                  'TED_z'
                ]]

        # Add the month dummies to the independent variables
        X = pd.concat([X, month_dummies], axis=1)

        # Convert all columns to numeric, coercing errors to NaN
        X = X.apply(pd.to_numeric, errors='coerce')
        y = pd.to_numeric(y, errors='coerce')

        # Drop rows with any NaN values
        X = X.dropna()
        y = y.loc[X.index]  # Ensure 'y' aligns with 'X' after dropping NaNs

        # Ensure that both X and y are aligned and are purely numeric
        if X.shape[0] > 0 and y.shape[0] > 0:  # Proceed only if there's valid data
            # Add a constant term to the model
            X = sm.add_constant(X)

            correlation = df[['Change in SWAV', 'TED']].corr()
            print(correlation)

            # Fit the model
            model = sm.OLS(y, X).fit()

            # Display the model summary
            print(model.summary())

            # Extract the coefficient and p-value for 'Change in SWAV'
            coef = round(model.params['Change in SWAV'], 2)
            p_value = round(model.pvalues['Change in SWAV'], 5)

            # Store the coefficient and p-value as a tuple
            result_row.append((coef, p_value))
        else:
            result_row.append((None, None))  # Store None for both if no valid data

    # Append the result row for this combination of days
    results.append(result_row)

# Define column names dynamically, ensuring "Days" is the first column
columns = ['Days']
for index in indices:
    columns.extend([f'{index} Coef'])  # Ensure you have columns for coefficients only

# Convert the results list to a DataFrame, extracting only the coefficients
results_df = pd.DataFrame([[row[0]] + [r[0] if isinstance(r, tuple) else None for r in row[1:]] for row in results], columns=columns)

# Define a function to apply the styling based on significance
def color_rows(row, original_results):
    colors = []
    for i in range(1, len(row)):  # Skip Days, then iterate through Coefs
        # Safely access the original tuple
        item = original_results[row.name][i]
        if isinstance(item, tuple):
            coef, p_value = item
            if coef is not None and p_value < 0.1:  # Only color if p-value < 0.1 (significant)
                if coef > 0:
                    colors.append('background-color: green')
                elif coef < 0:
                    colors.append('background-color: red')
                else:
                    colors.append('')
            else:
                colors.append('')  # No color for non-significant or None
        else:
            colors.append('')  # No color if item is not a tuple
    return [''] * 1 + colors  # No coloring for Days

# Apply the function to each row of the DataFrame, passing the original results
styled_df = results_df.style.apply(color_rows, axis=1, original_results=results)

# Display the styled DataFrame
print("Multicollinearity checks done")
styled_df
# Out:
# <ipython-input-222-bd9f86bb87fb>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TED_z'] = zscore(df['TED'])
# <ipython-input-222-bd9f86bb87fb>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TED_z*SWAV'] = df['Change in SWAV']*df['TED_z']
# <ipython-input-222-bd9f86bb87fb>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Covid_Stringency*SWAV'] = df['Change in SWAV']*df['Stringency_Change']
# <ipython-input-222-bd9f86bb87fb>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TED_z'] = zscore(df['TED'])
# <ipython-input-222-bd9f86bb87fb>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TED_z*SWAV'] = df['Change in SWAV']*df['TED_z']
# <ipython-input-222-bd9f86bb87fb>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Covid_Stringency*SWAV'] = df['Change in SWAV']*df['Stringency_Change']
#                 Change in SWAV       TED
# Change in SWAV        1.000000  0.011381
# TED                   0.011381  1.000000
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       % FTSE100 Change   R-squared:                       0.559
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     67.17
# Date:                Sat, 24 Aug 2024   Prob (F-statistic):          5.23e-164
# Time:                        17:21:05   Log-Likelihood:                -1125.9
# No. Observations:                1028   AIC:                             2292.
# Df Residuals:                    1008   BIC:                             2390.
# Df Model:                          19
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                        -0.0333      0.090     -0.369      0.712      -0.210       0.144
# Change in SWAV               -2.3887      2.370     -1.008      0.314      -7.040       2.263
# ADS_Change                   -0.0129      0.082     -0.158      0.874      -0.173       0.147
# EPU_Change                 5.591e-05      0.000      0.387      0.699      -0.000       0.000
# Previous % FTSE100 Change     0.0527      0.021      2.460      0.014       0.011       0.095
# % MSCI Change                 0.7679      0.023     33.777      0.000       0.723       0.812
# Vix Close                    -0.0017      0.003     -0.605      0.546      -0.007       0.004
# Rolling_Avg_Change_in_DCC  3.203e-13   1.65e-13      1.939      0.053    -3.9e-15    6.45e-13
# Stringency_Change             0.0410      0.101      0.404      0.686      -0.158       0.240
# Covid_Stringency*SWAV       -22.4204     10.601     -2.115      0.035     -43.223      -1.618
# TED_z*SWAV                   -4.1284      2.599     -1.588      0.113      -9.229       0.972
# TED_z                         0.0312      0.028      1.132      0.258      -0.023       0.085
# Month_3                       0.0615      0.105      0.587      0.558      -0.144       0.267
# Month_4                       0.0077      0.109      0.071      0.944      -0.206       0.222
# Month_5                       0.1237      0.106      1.166      0.244      -0.084       0.332
# Month_6                       0.0142      0.103      0.137      0.891      -0.189       0.217
# Month_7                       0.0014      0.104      0.013      0.990      -0.203       0.205
# Month_8                      -0.0337      0.104     -0.324      0.746      -0.238       0.170
# Month_9                       0.0646      0.105      0.613      0.540      -0.142       0.271
# Month_10                      0.0132      0.104      0.127      0.899      -0.191       0.217
# Month_11                      0.0142      0.106      0.135      0.893      -0.193       0.221
# ==============================================================================
# Omnibus:                       78.672   Durbin-Watson:                   2.259
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              394.929
# Skew:                          -0.036   Prob(JB):                     1.75e-86
# Kurtosis:                       6.036   Cond. No.                     6.46e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.17e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                 Change in SWAV       TED
# Change in SWAV        1.000000  0.011381
# TED                   0.011381  1.000000
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       % FTSE250 Change   R-squared:                       0.532
# Model:                            OLS   Adj. R-squared:                  0.524
# Method:                 Least Squares   F-statistic:                     60.40
# Date:                Sat, 24 Aug 2024   Prob (F-statistic):          1.72e-151
# Time:                        17:21:05   Log-Likelihood:                -1169.7
# No. Observations:                1028   AIC:                             2379.
# Df Residuals:                    1008   BIC:                             2478.
# Df Model:                          19
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         0.0911      0.094      0.966      0.334      -0.094       0.276
# Change in SWAV               -2.1039      2.474     -0.851      0.395      -6.958       2.750
# ADS_Change                    0.0684      0.085      0.802      0.423      -0.099       0.236
# EPU_Change                -1.157e-05      0.000     -0.077      0.939      -0.000       0.000
# Previous % FTSE250 Change     0.1425      0.022      6.335      0.000       0.098       0.187
# % MSCI Change                 0.7228      0.024     30.739      0.000       0.677       0.769
# Vix Close                    -0.0052      0.003     -1.782      0.075      -0.011       0.001
# Rolling_Avg_Change_in_DCC  1.958e-13   6.37e-14      3.072      0.002    7.07e-14    3.21e-13
# Stringency_Change             0.0023      0.106      0.022      0.983      -0.205       0.210
# Covid_Stringency*SWAV       -36.4360     11.123     -3.276      0.001     -58.263     -14.609
# TED_z*SWAV                  -10.2219      2.712     -3.769      0.000     -15.544      -4.899
# TED_z                         0.0530      0.029      1.849      0.065      -0.003       0.109
# Month_3                      -0.0409      0.109     -0.374      0.709      -0.256       0.174
# Month_4                      -0.0072      0.114     -0.064      0.949      -0.231       0.216
# Month_5                       0.0223      0.111      0.202      0.840      -0.195       0.240
# Month_6                      -0.0733      0.108     -0.680      0.497      -0.285       0.138
# Month_7                      -0.0250      0.109     -0.230      0.818      -0.238       0.188
# Month_8                       0.0331      0.108      0.305      0.760      -0.180       0.246
# Month_9                      -0.0268      0.110     -0.244      0.808      -0.242       0.189
# Month_10                      0.0023      0.109      0.021      0.983      -0.211       0.215
# Month_11                     -0.0381      0.110     -0.347      0.729      -0.254       0.178
# ==============================================================================
# Omnibus:                      224.433   Durbin-Watson:                   2.300
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3562.185
# Skew:                           0.535   Prob(JB):                         0.00
# Kurtosis:                      12.056   Cond. No.                     1.00e+19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.57e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# <ipython-input-222-bd9f86bb87fb>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TED_z'] = zscore(df['TED'])
# <ipython-input-222-bd9f86bb87fb>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TED_z*SWAV'] = df['Change in SWAV']*df['TED_z']
# <ipython-input-222-bd9f86bb87fb>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Covid_Stringency*SWAV'] = df['Change in SWAV']*df['Stringency_Change']
# <ipython-input-222-bd9f86bb87fb>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TED_z'] = zscore(df['TED'])
# <ipython-input-222-bd9f86bb87fb>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TED_z*SWAV'] = df['Change in SWAV']*df['TED_z']
# <ipython-input-222-bd9f86bb87fb>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Covid_Stringency*SWAV'] = df['Change in SWAV']*df['Stringency_Change']
#                 Change in SWAV       TED
# Change in SWAV        1.000000  0.011381
# TED                   0.011381  1.000000
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     % FTSESmallCap Change   R-squared:                       0.524
# Model:                               OLS   Adj. R-squared:                  0.515
# Method:                    Least Squares   F-statistic:                     58.34
# Date:                   Sat, 24 Aug 2024   Prob (F-statistic):          1.54e-147
# Time:                           17:21:05   Log-Likelihood:                -986.78
# No. Observations:                   1028   AIC:                             2014.
# Df Residuals:                       1008   BIC:                             2112.
# Df Model:                             19
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                              0.0373      0.079      0.471      0.637      -0.118       0.192
# Change in SWAV                    -2.1893      2.070     -1.057      0.291      -6.252       1.874
# ADS_Change                         0.1968      0.071      2.759      0.006       0.057       0.337
# EPU_Change                     -4.025e-05      0.000     -0.319      0.750      -0.000       0.000
# Previous % FTSESmallCap Change     0.1980      0.023      8.560      0.000       0.153       0.243
# % MSCI Change                      0.5536      0.020     28.023      0.000       0.515       0.592
# Vix Close                         -0.0039      0.002     -1.607      0.108      -0.009       0.001
# Rolling_Avg_Change_in_DCC      -6.447e-13   1.23e-13     -5.241      0.000   -8.86e-13   -4.03e-13
# Stringency_Change                 -0.1035      0.089     -1.167      0.243      -0.278       0.070
# Covid_Stringency*SWAV            -51.3614      9.436     -5.443      0.000     -69.878     -32.845
# TED_z*SWAV                       -10.3185      2.268     -4.549      0.000     -14.770      -5.867
# TED_z                              0.0531      0.024      2.214      0.027       0.006       0.100
# Month_3                            0.0608      0.092      0.664      0.507      -0.119       0.241
# Month_4                            0.0158      0.095      0.165      0.869      -0.172       0.203
# Month_5                            0.0437      0.093      0.471      0.638      -0.138       0.225
# Month_6                         2.904e-06      0.090   3.22e-05      1.000      -0.177       0.177
# Month_7                            0.0016      0.091      0.017      0.986      -0.177       0.180
# Month_8                            0.0412      0.091      0.454      0.650      -0.137       0.219
# Month_9                            0.0221      0.092      0.240      0.810      -0.158       0.203
# Month_10                           0.0230      0.091      0.253      0.800      -0.155       0.201
# Month_11                           0.0480      0.092      0.521      0.602      -0.133       0.229
# ==============================================================================
# Omnibus:                      421.427   Durbin-Watson:                   2.246
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            21436.299
# Skew:                           1.096   Prob(JB):                         0.00
# Kurtosis:                      25.263   Cond. No.                     6.02e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.12e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                 Change in SWAV       TED
# Change in SWAV        1.000000  0.018594
# TED                   0.018594  1.000000
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       % FTSE100 Change   R-squared:                       0.662
# Model:                            OLS   Adj. R-squared:                  0.656
# Method:                 Least Squares   F-statistic:                     98.79
# Date:                Sat, 24 Aug 2024   Prob (F-statistic):          5.48e-221
# Time:                        17:21:05   Log-Likelihood:                -1530.4
# No. Observations:                1028   AIC:                             3103.
# Df Residuals:                    1007   BIC:                             3206.
# Df Model:                          20
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         0.1047      0.136      0.769      0.442      -0.163       0.372
# Change in SWAV               -4.6374      2.623     -1.768      0.077      -9.785       0.510
# ADS_Change                    0.1597      0.049      3.250      0.001       0.063       0.256
# EPU_Change                -7.784e-05      0.000     -0.382      0.703      -0.000       0.000
# Previous % FTSE100 Change    -0.0989      0.019     -5.098      0.000      -0.137      -0.061
# % MSCI Change                 0.8034      0.021     39.162      0.000       0.763       0.844
# Vix Close                    -0.0144      0.004     -3.342      0.001      -0.023      -0.006
# Rolling_Avg_Change_in_DCC     0.0015      0.004      0.406      0.685      -0.006       0.009
# Stringency_Change             0.3178      0.068      4.705      0.000       0.185       0.450
# Covid_Stringency*SWAV        -2.6179      4.303     -0.608      0.543     -11.061       5.825
# TED_z*SWAV                   -2.2238      2.978     -0.747      0.455      -8.067       3.619
# TED_z                         0.0401      0.043      0.930      0.352      -0.045       0.125
# Month_3                       0.0598      0.156      0.384      0.701      -0.246       0.366
# Month_4                       0.1969      0.163      1.208      0.227      -0.123       0.517
# Month_5                       0.2751      0.159      1.726      0.085      -0.038       0.588
# Month_6                       0.0319      0.153      0.208      0.835      -0.269       0.333
# Month_7                      -0.1294      0.155     -0.836      0.403      -0.433       0.174
# Month_8                      -0.1885      0.154     -1.223      0.222      -0.491       0.114
# Month_9                       0.1915      0.156      1.224      0.221      -0.115       0.498
# Month_10                     -0.0319      0.155     -0.206      0.837      -0.335       0.272
# Month_11                      0.0024      0.157      0.015      0.988      -0.305       0.310
# ==============================================================================
# Omnibus:                       90.819   Durbin-Watson:                   0.948
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              415.792
# Skew:                           0.261   Prob(JB):                     5.15e-91
# Kurtosis:                       6.071   Cond. No.                     2.29e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.29e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# <ipython-input-222-bd9f86bb87fb>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TED_z'] = zscore(df['TED'])
# <ipython-input-222-bd9f86bb87fb>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TED_z*SWAV'] = df['Change in SWAV']*df['TED_z']
# <ipython-input-222-bd9f86bb87fb>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Covid_Stringency*SWAV'] = df['Change in SWAV']*df['Stringency_Change']
# <ipython-input-222-bd9f86bb87fb>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TED_z'] = zscore(df['TED'])
# <ipython-input-222-bd9f86bb87fb>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TED_z*SWAV'] = df['Change in SWAV']*df['TED_z']
# <ipython-input-222-bd9f86bb87fb>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Covid_Stringency*SWAV'] = df['Change in SWAV']*df['Stringency_Change']
#                 Change in SWAV       TED
# Change in SWAV        1.000000  0.018594
# TED                   0.018594  1.000000
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       % FTSE250 Change   R-squared:                       0.697
# Model:                            OLS   Adj. R-squared:                  0.691
# Method:                 Least Squares   F-statistic:                     115.6
# Date:                Sat, 24 Aug 2024   Prob (F-statistic):          3.67e-244
# Time:                        17:21:05   Log-Likelihood:                -1608.0
# No. Observations:                1028   AIC:                             3258.
# Df Residuals:                    1007   BIC:                             3362.
# Df Model:                          20
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         0.4373      0.147      2.973      0.003       0.149       0.726
# Change in SWAV                1.1285      2.830      0.399      0.690      -4.425       6.682
# ADS_Change                    0.2490      0.053      4.703      0.000       0.145       0.353
# EPU_Change                   -0.0005      0.000     -2.076      0.038      -0.001   -2.49e-05
# Previous % FTSE250 Change    -0.0242      0.020     -1.212      0.226      -0.063       0.015
# % MSCI Change                 0.9172      0.022     41.413      0.000       0.874       0.961
# Vix Close                    -0.0194      0.005     -4.184      0.000      -0.028      -0.010
# Rolling_Avg_Change_in_DCC     0.0021      0.004      0.542      0.588      -0.006       0.010
# Stringency_Change             0.2823      0.075      3.752      0.000       0.135       0.430
# Covid_Stringency*SWAV       -28.0281      4.642     -6.038      0.000     -37.137     -18.919
# TED_z*SWAV                    6.4242      3.222      1.994      0.046       0.101      12.747
# TED_z                        -0.0490      0.046     -1.055      0.292      -0.140       0.042
# Month_3                      -0.2835      0.168     -1.685      0.092      -0.614       0.047
# Month_4                       0.2034      0.176      1.157      0.248      -0.142       0.548
# Month_5                      -0.1246      0.172     -0.725      0.468      -0.462       0.213
# Month_6                      -0.3636      0.165     -2.200      0.028      -0.688      -0.039
# Month_7                      -0.3173      0.167     -1.902      0.058      -0.645       0.010
# Month_8                      -0.0989      0.166     -0.595      0.552      -0.425       0.227
# Month_9                      -0.2352      0.169     -1.394      0.164      -0.566       0.096
# Month_10                     -0.2184      0.167     -1.309      0.191      -0.546       0.109
# Month_11                     -0.2507      0.169     -1.484      0.138      -0.582       0.081
# ==============================================================================
# Omnibus:                      252.879   Durbin-Watson:                   1.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4801.876
# Skew:                          -0.615   Prob(JB):                         0.00
# Kurtosis:                      13.516   Cond. No.                     2.28e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.28e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                 Change in SWAV       TED
# Change in SWAV        1.000000  0.018594
# TED                   0.018594  1.000000
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     % FTSESmallCap Change   R-squared:                       0.675
# Model:                               OLS   Adj. R-squared:                  0.668
# Method:                    Least Squares   F-statistic:                     104.4
# Date:                   Sat, 24 Aug 2024   Prob (F-statistic):          5.50e-229
# Time:                           17:21:05   Log-Likelihood:                -1460.4
# No. Observations:                   1028   AIC:                             2963.
# Df Residuals:                       1007   BIC:                             3066.
# Df Model:                             20
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                              0.2286      0.127      1.797      0.073      -0.021       0.478
# Change in SWAV                     2.8818      2.452      1.175      0.240      -1.930       7.693
# ADS_Change                         0.2108      0.046      4.595      0.000       0.121       0.301
# EPU_Change                        -0.0004      0.000     -1.918      0.055      -0.001    8.37e-06
# Previous % FTSESmallCap Change     0.1591      0.022      7.137      0.000       0.115       0.203
# % MSCI Change                      0.7216      0.019     37.675      0.000       0.684       0.759
# Vix Close                         -0.0123      0.004     -3.070      0.002      -0.020      -0.004
# Rolling_Avg_Change_in_DCC         -0.0017      0.003     -0.489      0.625      -0.008       0.005
# Stringency_Change                  0.1567      0.067      2.324      0.020       0.024       0.289
# Covid_Stringency*SWAV            -36.1536      4.076     -8.869      0.000     -44.153     -28.155
# TED_z*SWAV                         4.4550      2.798      1.592      0.112      -1.036       9.945
# TED_z                             -0.0474      0.040     -1.178      0.239      -0.126       0.032
# Month_3                           -0.0459      0.146     -0.315      0.753      -0.332       0.240
# Month_4                            0.2149      0.153      1.409      0.159      -0.084       0.514
# Month_5                           -0.0042      0.149     -0.028      0.978      -0.296       0.288
# Month_6                           -0.1516      0.143     -1.058      0.290      -0.433       0.129
# Month_7                           -0.3139      0.145     -2.172      0.030      -0.598      -0.030
# Month_8                           -0.0544      0.144     -0.378      0.706      -0.337       0.228
# Month_9                           -0.0663      0.146     -0.454      0.650      -0.353       0.220
# Month_10                          -0.0965      0.144     -0.668      0.504      -0.380       0.187
# Month_11                          -0.0892      0.146     -0.609      0.543      -0.376       0.198
# ==============================================================================
# Omnibus:                      576.469   Durbin-Watson:                   0.941
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            36670.078
# Skew:                          -1.767   Prob(JB):                         0.00
# Kurtosis:                      32.045   Cond. No.                     2.30e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.3e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                 Change in SWAV       TED
# Change in SWAV        1.000000  0.017584
# TED                   0.017584  1.000000
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       % FTSE100 Change   R-squared:                       0.694
# Model:                            OLS   Adj. R-squared:                  0.688
# Method:                 Least Squares   F-statistic:                     114.3
# Date:                Sat, 24 Aug 2024   Prob (F-statistic):          2.17e-242
# Time:                        17:21:06   Log-Likelihood:                -1732.8
# No. Observations:                1028   AIC:                             3508.
# Df Residuals:                    1007   BIC:                             3611.
# Df Model:                          20
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         0.1473      0.162      0.908      0.364      -0.171       0.466
# Change in SWAV               -6.1079      2.870     -2.128      0.034     -11.741      -0.475
# ADS_Change                    0.1163      0.039      3.006      0.003       0.040       0.192
# EPU_Change                    0.0002      0.000      0.915      0.360      -0.000       0.001
# Previous % FTSE100 Change    -0.0742      0.020     -3.661      0.000      -0.114      -0.034
# % MSCI Change                 0.7905      0.019     41.159      0.000       0.753       0.828
# Vix Close                    -0.0218      0.005     -4.021      0.000      -0.032      -0.011
# Rolling_Avg_Change_in_DCC     0.0099      0.006      1.541      0.124      -0.003       0.022
# Stringency_Change             0.1622      0.061      2.650      0.008       0.042       0.282
# Covid_Stringency*SWAV        -7.9258      3.710     -2.136      0.033     -15.207      -0.645
# TED_z*SWAV                   -8.1569      3.184     -2.562      0.011     -14.404      -1.909
# TED_z                         0.1016      0.054      1.894      0.058      -0.004       0.207
# Month_3.0                     0.2221      0.184      1.210      0.227      -0.138       0.582
# Month_4.0                     0.2283      0.191      1.196      0.232      -0.146       0.603
# Month_5.0                     0.4709      0.183      2.570      0.010       0.111       0.830
# Month_6.0                    -0.0977      0.178     -0.548      0.584      -0.448       0.252
# Month_7.0                    -0.0820      0.180     -0.456      0.648      -0.434       0.270
# Month_8.0                    -0.2647      0.179     -1.479      0.139      -0.616       0.086
# Month_9.0                     0.2802      0.182      1.543      0.123      -0.076       0.637
# Month_10.0                    0.1544      0.178      0.869      0.385      -0.194       0.503
# Month_11.0                   -0.1642      0.202     -0.813      0.416      -0.560       0.232
# ==============================================================================
# Omnibus:                      112.264   Durbin-Watson:                   0.642
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              498.022
# Skew:                           0.411   Prob(JB):                    7.18e-109
# Kurtosis:                       6.309   Cond. No.                     1.81e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.81e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# <ipython-input-222-bd9f86bb87fb>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TED_z'] = zscore(df['TED'])
# <ipython-input-222-bd9f86bb87fb>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TED_z*SWAV'] = df['Change in SWAV']*df['TED_z']
# <ipython-input-222-bd9f86bb87fb>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Covid_Stringency*SWAV'] = df['Change in SWAV']*df['Stringency_Change']
# <ipython-input-222-bd9f86bb87fb>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TED_z'] = zscore(df['TED'])
# <ipython-input-222-bd9f86bb87fb>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TED_z*SWAV'] = df['Change in SWAV']*df['TED_z']
# <ipython-input-222-bd9f86bb87fb>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Covid_Stringency*SWAV'] = df['Change in SWAV']*df['Stringency_Change']
#                 Change in SWAV       TED
# Change in SWAV        1.000000  0.017584
# TED                   0.017584  1.000000
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       % FTSE250 Change   R-squared:                       0.758
# Model:                            OLS   Adj. R-squared:                  0.754
# Method:                 Least Squares   F-statistic:                     158.0
# Date:                Sat, 24 Aug 2024   Prob (F-statistic):          1.31e-293
# Time:                        17:21:06   Log-Likelihood:                -1794.0
# No. Observations:                1028   AIC:                             3630.
# Df Residuals:                    1007   BIC:                             3734.
# Df Model:                          20
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         0.5225      0.172      3.033      0.002       0.184       0.861
# Change in SWAV               -0.6223      3.045     -0.204      0.838      -6.599       5.354
# ADS_Change                    0.1448      0.041      3.536      0.000       0.064       0.225
# EPU_Change                   -0.0004      0.000     -1.479      0.139      -0.001       0.000
# Previous % FTSE250 Change    -0.0366      0.019     -1.898      0.058      -0.075       0.001
# % MSCI Change                 0.9830      0.021     47.916      0.000       0.943       1.023
# Vix Close                    -0.0219      0.006     -3.835      0.000      -0.033      -0.011
# Rolling_Avg_Change_in_DCC     0.0047      0.007      0.690      0.490      -0.009       0.018
# Stringency_Change             0.0823      0.069      1.200      0.231      -0.052       0.217
# Covid_Stringency*SWAV       -12.6105      3.937     -3.203      0.001     -20.336      -4.885
# TED_z*SWAV                    2.3361      3.360      0.695      0.487      -4.257       8.930
# TED_z                        -0.0264      0.057     -0.464      0.643      -0.138       0.085
# Month_3.0                    -0.2380      0.195     -1.223      0.222      -0.620       0.144
# Month_4.0                    -0.0025      0.203     -0.012      0.990      -0.400       0.395
# Month_5.0                    -0.0789      0.194     -0.407      0.684      -0.459       0.302
# Month_6.0                    -0.6254      0.189     -3.313      0.001      -0.996      -0.255
# Month_7.0                    -0.2486      0.191     -1.305      0.192      -0.622       0.125
# Month_8.0                    -0.2831      0.190     -1.491      0.136      -0.656       0.090
# Month_9.0                    -0.3800      0.193     -1.973      0.049      -0.758      -0.002
# Month_10.0                   -0.1818      0.188     -0.965      0.335      -0.551       0.188
# Month_11.0                   -0.4353      0.214     -2.035      0.042      -0.855      -0.016
# ==============================================================================
# Omnibus:                      203.946   Durbin-Watson:                   0.785
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4625.559
# Skew:                          -0.227   Prob(JB):                         0.00
# Kurtosis:                      13.382   Cond. No.                     1.80e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.8e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                 Change in SWAV       TED
# Change in SWAV        1.000000  0.017584
# TED                   0.017584  1.000000
# <ipython-input-222-bd9f86bb87fb>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TED_z'] = zscore(df['TED'])
# <ipython-input-222-bd9f86bb87fb>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TED_z*SWAV'] = df['Change in SWAV']*df['TED_z']
# <ipython-input-222-bd9f86bb87fb>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Covid_Stringency*SWAV'] = df['Change in SWAV']*df['Stringency_Change']
# <ipython-input-222-bd9f86bb87fb>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TED_z'] = zscore(df['TED'])
# <ipython-input-222-bd9f86bb87fb>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TED_z*SWAV'] = df['Change in SWAV']*df['TED_z']
# <ipython-input-222-bd9f86bb87fb>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Covid_Stringency*SWAV'] = df['Change in SWAV']*df['Stringency_Change']
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     % FTSESmallCap Change   R-squared:                       0.730
# Model:                               OLS   Adj. R-squared:                  0.724
# Method:                    Least Squares   F-statistic:                     135.9
# Date:                   Sat, 24 Aug 2024   Prob (F-statistic):          3.87e-269
# Time:                           17:21:06   Log-Likelihood:                -1707.1
# No. Observations:                   1028   AIC:                             3456.
# Df Residuals:                       1007   BIC:                             3560.
# Df Model:                             20
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                              0.2806      0.158      1.774      0.076      -0.030       0.591
# Change in SWAV                     4.8218      2.799      1.723      0.085      -0.670      10.314
# ADS_Change                         0.1056      0.038      2.806      0.005       0.032       0.180
# EPU_Change                        -0.0004      0.000     -1.856      0.064      -0.001    2.53e-05
# Previous % FTSESmallCap Change     0.0761      0.022      3.474      0.001       0.033       0.119
# % MSCI Change                      0.8308      0.019     43.848      0.000       0.794       0.868
# Vix Close                         -0.0087      0.005     -1.654      0.098      -0.019       0.002
# Rolling_Avg_Change_in_DCC          0.0083      0.006      1.323      0.186      -0.004       0.021
# Stringency_Change                 -0.0781      0.067     -1.172      0.241      -0.209       0.053
# Covid_Stringency*SWAV            -13.9325      3.619     -3.850      0.000     -21.034      -6.831
# TED_z*SWAV                         4.6183      3.090      1.494      0.135      -1.446      10.683
# TED_z                             -0.0130      0.052     -0.249      0.804      -0.116       0.090
# Month_3.0                         -0.1769      0.179     -0.989      0.323      -0.528       0.174
# Month_4.0                          0.0055      0.187      0.029      0.977      -0.361       0.372
# Month_5.0                         -0.0679      0.179     -0.380      0.704      -0.418       0.283
# Month_6.0                         -0.4383      0.174     -2.522      0.012      -0.779      -0.097
# Month_7.0                         -0.4033      0.175     -2.304      0.021      -0.747      -0.060
# Month_8.0                         -0.2777      0.175     -1.591      0.112      -0.620       0.065
# Month_9.0                         -0.2011      0.177     -1.136      0.256      -0.548       0.146
# Month_10.0                        -0.1734      0.173     -1.001      0.317      -0.513       0.167
# Month_11.0                        -0.3029      0.197     -1.537      0.125      -0.690       0.084
# ==============================================================================
# Omnibus:                      360.780   Durbin-Watson:                   0.673
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            27913.061
# Skew:                          -0.678   Prob(JB):                         0.00
# Kurtosis:                      28.492   Cond. No.                     1.80e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.8e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                 Change in SWAV       TED
# Change in SWAV        1.000000  0.058523
# TED                   0.058523  1.000000
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       % FTSE100 Change   R-squared:                       0.762
# Model:                            OLS   Adj. R-squared:                  0.757
# Method:                 Least Squares   F-statistic:                     161.1
# Date:                Sat, 24 Aug 2024   Prob (F-statistic):          8.76e-297
# Time:                        17:21:06   Log-Likelihood:                -1966.9
# No. Observations:                1028   AIC:                             3976.
# Df Residuals:                    1007   BIC:                             4079.
# Df Model:                          20
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         0.1015      0.216      0.469      0.639      -0.323       0.526
# Change in SWAV               -3.5415      3.060     -1.157      0.247      -9.546       2.463
# ADS_Change                    0.1084      0.027      3.969      0.000       0.055       0.162
# EPU_Change                    0.0005      0.000      1.532      0.126      -0.000       0.001
# Previous % FTSE100 Change    -0.1824      0.020     -8.918      0.000      -0.223      -0.142
# % MSCI Change                 0.7982      0.019     42.123      0.000       0.761       0.835
# Vix Close                    -0.0475      0.007     -6.690      0.000      -0.061      -0.034
# Rolling_Avg_Change_in_DCC     0.0087      0.015      0.586      0.558      -0.020       0.038
# Stringency_Change             0.0887      0.057      1.553      0.121      -0.023       0.201
# Covid_Stringency*SWAV        -0.7926      3.362     -0.236      0.814      -7.389       5.804
# TED_z*SWAV                  -15.8343      3.282     -4.824      0.000     -22.275      -9.394
# TED_z                         0.0229      0.075      0.305      0.761      -0.125       0.170
# Month_3                       0.5017      0.240      2.090      0.037       0.031       0.973
# Month_4                       1.0026      0.257      3.907      0.000       0.499       1.506
# Month_5                       1.4922      0.249      5.993      0.000       1.004       1.981
# Month_6                       0.3155      0.237      1.332      0.183      -0.149       0.780
# Month_7                      -0.1719      0.238     -0.721      0.471      -0.639       0.296
# Month_8                      -0.1670      0.237     -0.706      0.481      -0.631       0.297
# Month_9                       0.1167      0.240      0.486      0.627      -0.355       0.588
# Month_10                      0.4320      0.240      1.803      0.072      -0.038       0.902
# Month_11                      0.7904      0.241      3.285      0.001       0.318       1.263
# ==============================================================================
# Omnibus:                       53.437   Durbin-Watson:                   0.408
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              125.390
# Skew:                           0.285   Prob(JB):                     5.91e-28
# Kurtosis:                       4.613   Cond. No.                     1.44e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.44e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# <ipython-input-222-bd9f86bb87fb>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TED_z'] = zscore(df['TED'])
# <ipython-input-222-bd9f86bb87fb>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TED_z*SWAV'] = df['Change in SWAV']*df['TED_z']
# <ipython-input-222-bd9f86bb87fb>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Covid_Stringency*SWAV'] = df['Change in SWAV']*df['Stringency_Change']
#                 Change in SWAV       TED
# Change in SWAV        1.000000  0.058523
# TED                   0.058523  1.000000
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       % FTSE250 Change   R-squared:                       0.837
# Model:                            OLS   Adj. R-squared:                  0.834
# Method:                 Least Squares   F-statistic:                     259.1
# Date:                Sat, 24 Aug 2024   Prob (F-statistic):               0.00
# Time:                        17:21:06   Log-Likelihood:                -1935.6
# No. Observations:                1028   AIC:                             3913.
# Df Residuals:                    1007   BIC:                             4017.
# Df Model:                          20
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         0.5237      0.210      2.493      0.013       0.112       0.936
# Change in SWAV                2.6687      2.970      0.899      0.369      -3.159       8.497
# ADS_Change                    0.1034      0.027      3.884      0.000       0.051       0.156
# EPU_Change                   -0.0005      0.000     -1.898      0.058      -0.001    1.85e-05
# Previous % FTSE250 Change    -0.1080      0.018     -6.163      0.000      -0.142      -0.074
# % MSCI Change                 0.9765      0.018     52.911      0.000       0.940       1.013
# Vix Close                    -0.0299      0.007     -4.379      0.000      -0.043      -0.016
# Rolling_Avg_Change_in_DCC     0.0015      0.014      0.106      0.916      -0.027       0.030
# Stringency_Change            -0.1038      0.055     -1.874      0.061      -0.212       0.005
# Covid_Stringency*SWAV        -4.4466      3.255     -1.366      0.172     -10.833       1.940
# TED_z*SWAV                   -9.7362      3.246     -2.999      0.003     -16.106      -3.366
# TED_z                        -0.1425      0.073     -1.950      0.051      -0.286       0.001
# Month_3                      -0.2218      0.233     -0.953      0.341      -0.678       0.235
# Month_4                       0.7354      0.247      2.976      0.003       0.250       1.220
# Month_5                       0.2155      0.241      0.894      0.371      -0.257       0.688
# Month_6                      -0.6794      0.228     -2.976      0.003      -1.127      -0.231
# Month_7                      -0.8869      0.231     -3.845      0.000      -1.339      -0.434
# Month_8                       0.0851      0.230      0.371      0.711      -0.365       0.536
# Month_9                      -0.4779      0.233     -2.050      0.041      -0.935      -0.020
# Month_10                     -0.3743      0.232     -1.611      0.107      -0.830       0.081
# Month_11                      0.0028      0.233      0.012      0.990      -0.454       0.459
# ==============================================================================
# Omnibus:                       46.442   Durbin-Watson:                   0.582
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              133.499
# Skew:                           0.125   Prob(JB):                     1.03e-29
# Kurtosis:                       4.748   Cond. No.                     1.44e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.44e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                 Change in SWAV       TED
# Change in SWAV        1.000000  0.058523
# TED                   0.058523  1.000000
# <ipython-input-222-bd9f86bb87fb>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TED_z'] = zscore(df['TED'])
# <ipython-input-222-bd9f86bb87fb>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TED_z*SWAV'] = df['Change in SWAV']*df['TED_z']
# <ipython-input-222-bd9f86bb87fb>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Covid_Stringency*SWAV'] = df['Change in SWAV']*df['Stringency_Change']
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     % FTSESmallCap Change   R-squared:                       0.811
# Model:                               OLS   Adj. R-squared:                  0.808
# Method:                    Least Squares   F-statistic:                     216.7
# Date:                   Sat, 24 Aug 2024   Prob (F-statistic):               0.00
# Time:                           17:21:07   Log-Likelihood:                -1923.7
# No. Observations:                   1028   AIC:                             3889.
# Df Residuals:                       1007   BIC:                             3993.
# Df Model:                             20
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                             -0.1517      0.207     -0.731      0.465      -0.559       0.255
# Change in SWAV                     6.9853      2.945      2.372      0.018       1.206      12.765
# ADS_Change                         0.0551      0.026      2.084      0.037       0.003       0.107
# EPU_Change                        -0.0006      0.000     -2.004      0.045      -0.001   -1.18e-05
# Previous % FTSESmallCap Change    -0.0813      0.020     -4.047      0.000      -0.121      -0.042
# % MSCI Change                      0.8581      0.018     47.041      0.000       0.822       0.894
# Vix Close                         -0.0020      0.007     -0.294      0.769      -0.015       0.011
# Rolling_Avg_Change_in_DCC          0.0129      0.014      0.906      0.365      -0.015       0.041
# Stringency_Change                 -0.4178      0.055     -7.637      0.000      -0.525      -0.310
# Covid_Stringency*SWAV             -2.4016      3.212     -0.748      0.455      -8.704       3.901
# TED_z*SWAV                        -2.9136      3.290     -0.886      0.376      -9.369       3.542
# TED_z                             -0.1153      0.073     -1.585      0.113      -0.258       0.027
# Month_3                            0.0221      0.230      0.096      0.924      -0.429       0.473
# Month_4                            1.0440      0.245      4.263      0.000       0.563       1.525
# Month_5                            0.6539      0.238      2.742      0.006       0.186       1.122
# Month_6                           -0.0308      0.226     -0.136      0.892      -0.474       0.412
# Month_7                           -1.0095      0.228     -4.427      0.000      -1.457      -0.562
# Month_8                            0.1125      0.227      0.496      0.620      -0.333       0.558
# Month_9                           -0.1864      0.230     -0.809      0.419      -0.639       0.266
# Month_10                           0.0692      0.230      0.301      0.763      -0.381       0.520
# Month_11                           0.2110      0.230      0.918      0.359      -0.240       0.662
# ==============================================================================
# Omnibus:                      190.918   Durbin-Watson:                   0.480
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2934.757
# Skew:                           0.353   Prob(JB):                         0.00
# Kurtosis:                      11.247   Cond. No.                     1.45e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.45e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Multicollinearity checks done
# <style type="text/css">
# #T_d548b_row1_col1, #T_d548b_row2_col1 {
#   background-color: red;
# }
# #T_d548b_row2_col3, #T_d548b_row3_col3 {
#   background-color: green;
# }
# </style>
# <table id="T_d548b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d548b_level0_col0" class="col_heading level0 col0" >Days</th>
#       <th id="T_d548b_level0_col1" class="col_heading level0 col1" >FTSE100 Coef</th>
#       <th id="T_d548b_level0_col2" class="col_heading level0 col2" >FTSE250 Coef</th>
#       <th id="T_d548b_level0_col3" class="col_heading level0 col3" >FTSESmallCap Coef</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d548b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d548b_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_d548b_row0_col1" class="data row0 col1" >-2.390000</td>
#       <td id="T_d548b_row0_col2" class="data row0 col2" >-2.100000</td>
#       <td id="T_d548b_row0_col3" class="data row0 col3" >-2.190000</td>
#     </tr>
#     <tr>
#       <th id="T_d548b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d548b_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_d548b_row1_col1" class="data row1 col1" >-4.640000</td>
#       <td id="T_d548b_row1_col2" class="data row1 col2" >1.130000</td>
#       <td id="T_d548b_row1_col3" class="data row1 col3" >2.880000</td>
#     </tr>
#     <tr>
#       <th id="T_d548b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d548b_row2_col0" class="data row2 col0" >5</td>
#       <td id="T_d548b_row2_col1" class="data row2 col1" >-6.110000</td>
#       <td id="T_d548b_row2_col2" class="data row2 col2" >-0.620000</td>
#       <td id="T_d548b_row2_col3" class="data row2 col3" >4.820000</td>
#     </tr>
#     <tr>
#       <th id="T_d548b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d548b_row3_col0" class="data row3 col0" >10</td>
#       <td id="T_d548b_row3_col1" class="data row3 col1" >-3.540000</td>
#       <td id="T_d548b_row3_col2" class="data row3 col2" >2.670000</td>
#       <td id="T_d548b_row3_col3" class="data row3 col3" >6.990000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_5_day_TED['Date'] = pd.to_datetime(df['Date'])

# Plotting the TED spread across the selected years
plt.figure(figsize=(10, 6))
plt.plot(df_5_day_TED['Date'], df_5_day_TED['TED'], label='TED Spread', color='blue')
plt.title('TED Spread from 2017 to 2022')
plt.xlabel('Date')
plt.ylabel('TED Spread')
plt.grid(True)
plt.legend()
plt.show()
