# %% [markdown]
# <a href="https://colab.research.google.com/github/ThalyaGIT/UK-Music-Index-Returns/blob/main/3_data-analysis_notebooks/UK_Music_Happiness_and_Index_Returns_By_Year.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import packages
import pandas as pd
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from tabulate import tabulate

# %%
# Open CSV into dataframe
url_1_day = 'https://raw.githubusercontent.com/ThalyaGIT/UK-Music-Index-Returns/main/0-data-gold/data_1_days.csv'
url_3_day = 'https://raw.githubusercontent.com/ThalyaGIT/UK-Music-Index-Returns/main/0-data-gold/data_3_days.csv'
url_5_day = 'https://raw.githubusercontent.com/ThalyaGIT/UK-Music-Index-Returns/main/0-data-gold/data_5_days.csv'
url_10_day = 'https://raw.githubusercontent.com/ThalyaGIT/UK-Music-Index-Returns/main/0-data-gold/data_10_days.csv'
url_20_day = 'https://raw.githubusercontent.com/ThalyaGIT/UK-Music-Index-Returns/main/0-data-gold/data_20_days.csv'

df_1_day = pd.read_csv(url_1_day)
df_3_day = pd.read_csv(url_3_day)
df_5_day = pd.read_csv(url_5_day)
df_10_day = pd.read_csv(url_10_day)
df_20_day = pd.read_csv(url_20_day)

# # Attempt to convert the 'Date' column to datetime, coercing errors to NaT (Not a Time)
df_1_day['Date'] = pd.to_datetime(df_1_day['Date'], errors='coerce')

# %% [markdown]
# # **MSCI UK with No Controlling Variables**

# %%
days_list = [1, 3, 5, 10, 20]

for days in days_list:
    # Assuming df_1_day, df_3_day, etc. are the corresponding DataFrames for each day
    df = globals()[f'df_{days}_day']  # Dynamically access each DataFrame

    y = df['% MSCIUK Change']
    X = df[['Change in SWAV']]

    X = sm.add_constant(X)
    model = sm.OLS(y, X).fit()

    coef = round(model.params['Change in SWAV'], 2)
    p_value = round(model.pvalues['Change in SWAV'], 5)

    print(f"{days} Days")
    print(f"Change in SWAV: {coef}")
    print(f"P-value: {p_value}\n")
# Out:
# 1 Days
# Change in SWAV: -3.07
# P-value: 0.30591
#
# 3 Days
# Change in SWAV: -8.0
# P-value: 0.04961
#
# 5 Days
# Change in SWAV: -13.66
# P-value: 0.00249
#
# 10 Days
# Change in SWAV: -24.2
# P-value: 0.0
#
# 20 Days
# Change in SWAV: -32.13
# P-value: 0.0

# %% [markdown]
# # **MSCIUK**

# %%
import pandas as pd
from tabulate import tabulate

# Initialize an empty list to store results
results = []

days_list = [1, 3, 5, 10, 20]
years_list = range(2017, 2023)  # Years from 2017 to 2022

for year in years_list:
    for days in days_list:
        df = globals()[f'df_{days}_day']  # Dynamically access each DataFrame

        # Ensure 'Date' column is in datetime format
        df['Date'] = pd.to_datetime(df['Date'])
        # Filter for the specific year
        df_filtered = df[df['Date'].dt.year == year]

        y = df_filtered['% MSCIUK Change']
        X = df_filtered[['Change in SWAV',
                         'ADS_Change',
                         'EPU_Change',
                         'Previous % MSCIUK Change',
                         '% MSCI Change',
                         'Vix Close',
                         'Rolling_Avg_Change_in_DCC',
                         'Stringency_Change'
                         ,'TED'
                         ]]

        X = sm.add_constant(X)
        model = sm.OLS(y, X).fit()

        coef = round(model.params['Change in SWAV'], 2)
        p_value = round(model.pvalues['Change in SWAV'], 5)

        # Append the results to the list with year included
        results.append([year, days, coef, p_value])

# Convert the results list to a DataFrame
results_df = pd.DataFrame(results, columns=['Year', 'Days', 'Change in SWAV', 'P-value'])

# Define a function to apply the styling
def color_rows(row):
    if row['P-value'] < 0.1:
        if row['Change in SWAV'] > 0:
            return ['background-color: green']*len(row)
        elif row['Change in SWAV'] < 0:
            return ['background-color: red']*len(row)
    return ['background-color: grey']*len(row)

# Apply the function to each row of the DataFrame
styled_df = results_df.style.apply(color_rows, axis=1)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_5bc4a_row0_col0, #T_5bc4a_row0_col1, #T_5bc4a_row0_col2, #T_5bc4a_row0_col3, #T_5bc4a_row1_col0, #T_5bc4a_row1_col1, #T_5bc4a_row1_col2, #T_5bc4a_row1_col3, #T_5bc4a_row3_col0, #T_5bc4a_row3_col1, #T_5bc4a_row3_col2, #T_5bc4a_row3_col3, #T_5bc4a_row5_col0, #T_5bc4a_row5_col1, #T_5bc4a_row5_col2, #T_5bc4a_row5_col3, #T_5bc4a_row6_col0, #T_5bc4a_row6_col1, #T_5bc4a_row6_col2, #T_5bc4a_row6_col3, #T_5bc4a_row10_col0, #T_5bc4a_row10_col1, #T_5bc4a_row10_col2, #T_5bc4a_row10_col3, #T_5bc4a_row12_col0, #T_5bc4a_row12_col1, #T_5bc4a_row12_col2, #T_5bc4a_row12_col3, #T_5bc4a_row13_col0, #T_5bc4a_row13_col1, #T_5bc4a_row13_col2, #T_5bc4a_row13_col3, #T_5bc4a_row14_col0, #T_5bc4a_row14_col1, #T_5bc4a_row14_col2, #T_5bc4a_row14_col3, #T_5bc4a_row15_col0, #T_5bc4a_row15_col1, #T_5bc4a_row15_col2, #T_5bc4a_row15_col3, #T_5bc4a_row16_col0, #T_5bc4a_row16_col1, #T_5bc4a_row16_col2, #T_5bc4a_row16_col3, #T_5bc4a_row17_col0, #T_5bc4a_row17_col1, #T_5bc4a_row17_col2, #T_5bc4a_row17_col3, #T_5bc4a_row18_col0, #T_5bc4a_row18_col1, #T_5bc4a_row18_col2, #T_5bc4a_row18_col3, #T_5bc4a_row20_col0, #T_5bc4a_row20_col1, #T_5bc4a_row20_col2, #T_5bc4a_row20_col3, #T_5bc4a_row22_col0, #T_5bc4a_row22_col1, #T_5bc4a_row22_col2, #T_5bc4a_row22_col3, #T_5bc4a_row26_col0, #T_5bc4a_row26_col1, #T_5bc4a_row26_col2, #T_5bc4a_row26_col3, #T_5bc4a_row27_col0, #T_5bc4a_row27_col1, #T_5bc4a_row27_col2, #T_5bc4a_row27_col3, #T_5bc4a_row28_col0, #T_5bc4a_row28_col1, #T_5bc4a_row28_col2, #T_5bc4a_row28_col3, #T_5bc4a_row29_col0, #T_5bc4a_row29_col1, #T_5bc4a_row29_col2, #T_5bc4a_row29_col3 {
#   background-color: grey;
# }
# #T_5bc4a_row2_col0, #T_5bc4a_row2_col1, #T_5bc4a_row2_col2, #T_5bc4a_row2_col3, #T_5bc4a_row7_col0, #T_5bc4a_row7_col1, #T_5bc4a_row7_col2, #T_5bc4a_row7_col3, #T_5bc4a_row8_col0, #T_5bc4a_row8_col1, #T_5bc4a_row8_col2, #T_5bc4a_row8_col3, #T_5bc4a_row9_col0, #T_5bc4a_row9_col1, #T_5bc4a_row9_col2, #T_5bc4a_row9_col3, #T_5bc4a_row11_col0, #T_5bc4a_row11_col1, #T_5bc4a_row11_col2, #T_5bc4a_row11_col3, #T_5bc4a_row21_col0, #T_5bc4a_row21_col1, #T_5bc4a_row21_col2, #T_5bc4a_row21_col3, #T_5bc4a_row23_col0, #T_5bc4a_row23_col1, #T_5bc4a_row23_col2, #T_5bc4a_row23_col3, #T_5bc4a_row24_col0, #T_5bc4a_row24_col1, #T_5bc4a_row24_col2, #T_5bc4a_row24_col3, #T_5bc4a_row25_col0, #T_5bc4a_row25_col1, #T_5bc4a_row25_col2, #T_5bc4a_row25_col3 {
#   background-color: red;
# }
# #T_5bc4a_row4_col0, #T_5bc4a_row4_col1, #T_5bc4a_row4_col2, #T_5bc4a_row4_col3, #T_5bc4a_row19_col0, #T_5bc4a_row19_col1, #T_5bc4a_row19_col2, #T_5bc4a_row19_col3 {
#   background-color: green;
# }
# </style>
# <table id="T_5bc4a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5bc4a_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_5bc4a_level0_col1" class="col_heading level0 col1" >Days</th>
#       <th id="T_5bc4a_level0_col2" class="col_heading level0 col2" >Change in SWAV</th>
#       <th id="T_5bc4a_level0_col3" class="col_heading level0 col3" >P-value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5bc4a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5bc4a_row0_col0" class="data row0 col0" >2017</td>
#       <td id="T_5bc4a_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_5bc4a_row0_col2" class="data row0 col2" >1.440000</td>
#       <td id="T_5bc4a_row0_col3" class="data row0 col3" >0.610220</td>
#     </tr>
#     <tr>
#       <th id="T_5bc4a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5bc4a_row1_col0" class="data row1 col0" >2017</td>
#       <td id="T_5bc4a_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_5bc4a_row1_col2" class="data row1 col2" >-4.630000</td>
#       <td id="T_5bc4a_row1_col3" class="data row1 col3" >0.170400</td>
#     </tr>
#     <tr>
#       <th id="T_5bc4a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5bc4a_row2_col0" class="data row2 col0" >2017</td>
#       <td id="T_5bc4a_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_5bc4a_row2_col2" class="data row2 col2" >-9.710000</td>
#       <td id="T_5bc4a_row2_col3" class="data row2 col3" >0.024360</td>
#     </tr>
#     <tr>
#       <th id="T_5bc4a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5bc4a_row3_col0" class="data row3 col0" >2017</td>
#       <td id="T_5bc4a_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_5bc4a_row3_col2" class="data row3 col2" >-0.200000</td>
#       <td id="T_5bc4a_row3_col3" class="data row3 col3" >0.965320</td>
#     </tr>
#     <tr>
#       <th id="T_5bc4a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5bc4a_row4_col0" class="data row4 col0" >2017</td>
#       <td id="T_5bc4a_row4_col1" class="data row4 col1" >20</td>
#       <td id="T_5bc4a_row4_col2" class="data row4 col2" >20.960000</td>
#       <td id="T_5bc4a_row4_col3" class="data row4 col3" >0.000370</td>
#     </tr>
#     <tr>
#       <th id="T_5bc4a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5bc4a_row5_col0" class="data row5 col0" >2018</td>
#       <td id="T_5bc4a_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_5bc4a_row5_col2" class="data row5 col2" >3.200000</td>
#       <td id="T_5bc4a_row5_col3" class="data row5 col3" >0.265510</td>
#     </tr>
#     <tr>
#       <th id="T_5bc4a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5bc4a_row6_col0" class="data row6 col0" >2018</td>
#       <td id="T_5bc4a_row6_col1" class="data row6 col1" >3</td>
#       <td id="T_5bc4a_row6_col2" class="data row6 col2" >6.480000</td>
#       <td id="T_5bc4a_row6_col3" class="data row6 col3" >0.109830</td>
#     </tr>
#     <tr>
#       <th id="T_5bc4a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5bc4a_row7_col0" class="data row7 col0" >2018</td>
#       <td id="T_5bc4a_row7_col1" class="data row7 col1" >5</td>
#       <td id="T_5bc4a_row7_col2" class="data row7 col2" >-7.290000</td>
#       <td id="T_5bc4a_row7_col3" class="data row7 col3" >0.087330</td>
#     </tr>
#     <tr>
#       <th id="T_5bc4a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5bc4a_row8_col0" class="data row8 col0" >2018</td>
#       <td id="T_5bc4a_row8_col1" class="data row8 col1" >10</td>
#       <td id="T_5bc4a_row8_col2" class="data row8 col2" >-9.440000</td>
#       <td id="T_5bc4a_row8_col3" class="data row8 col3" >0.068230</td>
#     </tr>
#     <tr>
#       <th id="T_5bc4a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5bc4a_row9_col0" class="data row9 col0" >2018</td>
#       <td id="T_5bc4a_row9_col1" class="data row9 col1" >20</td>
#       <td id="T_5bc4a_row9_col2" class="data row9 col2" >-19.070000</td>
#       <td id="T_5bc4a_row9_col3" class="data row9 col3" >0.003870</td>
#     </tr>
#     <tr>
#       <th id="T_5bc4a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5bc4a_row10_col0" class="data row10 col0" >2019</td>
#       <td id="T_5bc4a_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_5bc4a_row10_col2" class="data row10 col2" >-1.330000</td>
#       <td id="T_5bc4a_row10_col3" class="data row10 col3" >0.647660</td>
#     </tr>
#     <tr>
#       <th id="T_5bc4a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5bc4a_row11_col0" class="data row11 col0" >2019</td>
#       <td id="T_5bc4a_row11_col1" class="data row11 col1" >3</td>
#       <td id="T_5bc4a_row11_col2" class="data row11 col2" >-6.980000</td>
#       <td id="T_5bc4a_row11_col3" class="data row11 col3" >0.065320</td>
#     </tr>
#     <tr>
#       <th id="T_5bc4a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5bc4a_row12_col0" class="data row12 col0" >2019</td>
#       <td id="T_5bc4a_row12_col1" class="data row12 col1" >5</td>
#       <td id="T_5bc4a_row12_col2" class="data row12 col2" >0.980000</td>
#       <td id="T_5bc4a_row12_col3" class="data row12 col3" >0.802010</td>
#     </tr>
#     <tr>
#       <th id="T_5bc4a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5bc4a_row13_col0" cla

# %% [markdown]
# ## **Next Period's MSCI Change**

# %%
import pandas as pd
from tabulate import tabulate

# Initialize an empty list to store results
results = []

days_list = [1, 3, 5, 10, 20]
years_list = range(2017, 2023)  # Years from 2017 to 2022

for year in years_list:
    for days in days_list:
        df = globals()[f'df_{days}_day']  # Dynamically access each DataFrame

        # Ensure 'Date' column is in datetime format
        df['Date'] = pd.to_datetime(df['Date'])
        # Filter for the specific year
        df_filtered = df[df['Date'].dt.year == year]

        y = df_filtered['Next % MSCIUK Change']
        X = df_filtered[['Change in SWAV',
                         'ADS_Change',
                         'EPU_Change',
                         '% MSCIUK Change',
                         'Next % MSCI Change',
                         'Vix Close',
                         'Rolling_Avg_Change_in_DCC',
                         'Stringency_Change'
                         ]]

        X = sm.add_constant(X)
        model = sm.OLS(y, X).fit()

        coef = round(model.params['Change in SWAV'], 2)
        p_value = round(model.pvalues['Change in SWAV'], 5)

        # Append the results to the list with year included
        results.append([year, days, coef, p_value])

# Convert the results list to a DataFrame
results_df = pd.DataFrame(results, columns=['Year', 'Days', 'Change in SWAV', 'P-value'])

# Define a function to apply the styling
def color_rows(row):
    if row['P-value'] < 0.1:
        if row['Change in SWAV'] > 0:
            return ['background-color: green']*len(row)
        elif row['Change in SWAV'] < 0:
            return ['background-color: red']*len(row)
    return ['background-color: grey']*len(row)

# Apply the function to each row of the DataFrame
styled_df = results_df.style.apply(color_rows, axis=1)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_cde48_row0_col0, #T_cde48_row0_col1, #T_cde48_row0_col2, #T_cde48_row0_col3, #T_cde48_row1_col0, #T_cde48_row1_col1, #T_cde48_row1_col2, #T_cde48_row1_col3, #T_cde48_row5_col0, #T_cde48_row5_col1, #T_cde48_row5_col2, #T_cde48_row5_col3, #T_cde48_row6_col0, #T_cde48_row6_col1, #T_cde48_row6_col2, #T_cde48_row6_col3, #T_cde48_row7_col0, #T_cde48_row7_col1, #T_cde48_row7_col2, #T_cde48_row7_col3, #T_cde48_row8_col0, #T_cde48_row8_col1, #T_cde48_row8_col2, #T_cde48_row8_col3, #T_cde48_row10_col0, #T_cde48_row10_col1, #T_cde48_row10_col2, #T_cde48_row10_col3, #T_cde48_row12_col0, #T_cde48_row12_col1, #T_cde48_row12_col2, #T_cde48_row12_col3, #T_cde48_row13_col0, #T_cde48_row13_col1, #T_cde48_row13_col2, #T_cde48_row13_col3, #T_cde48_row14_col0, #T_cde48_row14_col1, #T_cde48_row14_col2, #T_cde48_row14_col3, #T_cde48_row15_col0, #T_cde48_row15_col1, #T_cde48_row15_col2, #T_cde48_row15_col3, #T_cde48_row18_col0, #T_cde48_row18_col1, #T_cde48_row18_col2, #T_cde48_row18_col3, #T_cde48_row20_col0, #T_cde48_row20_col1, #T_cde48_row20_col2, #T_cde48_row20_col3, #T_cde48_row21_col0, #T_cde48_row21_col1, #T_cde48_row21_col2, #T_cde48_row21_col3, #T_cde48_row22_col0, #T_cde48_row22_col1, #T_cde48_row22_col2, #T_cde48_row22_col3, #T_cde48_row23_col0, #T_cde48_row23_col1, #T_cde48_row23_col2, #T_cde48_row23_col3, #T_cde48_row25_col0, #T_cde48_row25_col1, #T_cde48_row25_col2, #T_cde48_row25_col3, #T_cde48_row26_col0, #T_cde48_row26_col1, #T_cde48_row26_col2, #T_cde48_row26_col3, #T_cde48_row27_col0, #T_cde48_row27_col1, #T_cde48_row27_col2, #T_cde48_row27_col3, #T_cde48_row28_col0, #T_cde48_row28_col1, #T_cde48_row28_col2, #T_cde48_row28_col3 {
#   background-color: grey;
# }
# #T_cde48_row2_col0, #T_cde48_row2_col1, #T_cde48_row2_col2, #T_cde48_row2_col3, #T_cde48_row3_col0, #T_cde48_row3_col1, #T_cde48_row3_col2, #T_cde48_row3_col3, #T_cde48_row4_col0, #T_cde48_row4_col1, #T_cde48_row4_col2, #T_cde48_row4_col3, #T_cde48_row9_col0, #T_cde48_row9_col1, #T_cde48_row9_col2, #T_cde48_row9_col3, #T_cde48_row11_col0, #T_cde48_row11_col1, #T_cde48_row11_col2, #T_cde48_row11_col3, #T_cde48_row19_col0, #T_cde48_row19_col1, #T_cde48_row19_col2, #T_cde48_row19_col3, #T_cde48_row24_col0, #T_cde48_row24_col1, #T_cde48_row24_col2, #T_cde48_row24_col3, #T_cde48_row29_col0, #T_cde48_row29_col1, #T_cde48_row29_col2, #T_cde48_row29_col3 {
#   background-color: green;
# }
# #T_cde48_row16_col0, #T_cde48_row16_col1, #T_cde48_row16_col2, #T_cde48_row16_col3, #T_cde48_row17_col0, #T_cde48_row17_col1, #T_cde48_row17_col2, #T_cde48_row17_col3 {
#   background-color: red;
# }
# </style>
# <table id="T_cde48" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cde48_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_cde48_level0_col1" class="col_heading level0 col1" >Days</th>
#       <th id="T_cde48_level0_col2" class="col_heading level0 col2" >Change in SWAV</th>
#       <th id="T_cde48_level0_col3" class="col_heading level0 col3" >P-value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cde48_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cde48_row0_col0" class="data row0 col0" >2017</td>
#       <td id="T_cde48_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_cde48_row0_col2" class="data row0 col2" >-1.850000</td>
#       <td id="T_cde48_row0_col3" class="data row0 col3" >0.506500</td>
#     </tr>
#     <tr>
#       <th id="T_cde48_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cde48_row1_col0" class="data row1 col0" >2017</td>
#       <td id="T_cde48_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_cde48_row1_col2" class="data row1 col2" >-1.740000</td>
#       <td id="T_cde48_row1_col3" class="data row1 col3" >0.608490</td>
#     </tr>
#     <tr>
#       <th id="T_cde48_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cde48_row2_col0" class="data row2 col0" >2017</td>
#       <td id="T_cde48_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_cde48_row2_col2" class="data row2 col2" >7.980000</td>
#       <td id="T_cde48_row2_col3" class="data row2 col3" >0.072000</td>
#     </tr>
#     <tr>
#       <th id="T_cde48_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cde48_row3_col0" class="data row3 col0" >2017</td>
#       <td id="T_cde48_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_cde48_row3_col2" class="data row3 col2" >23.330000</td>
#       <td id="T_cde48_row3_col3" class="data row3 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cde48_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cde48_row4_col0" class="data row4 col0" >2017</td>
#       <td id="T_cde48_row4_col1" class="data row4 col1" >20</td>
#       <td id="T_cde48_row4_col2" class="data row4 col2" >12.850000</td>
#       <td id="T_cde48_row4_col3" class="data row4 col3" >0.010130</td>
#     </tr>
#     <tr>
#       <th id="T_cde48_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cde48_row5_col0" class="data row5 col0" >2018</td>
#       <td id="T_cde48_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_cde48_row5_col2" class="data row5 col2" >-0.120000</td>
#       <td id="T_cde48_row5_col3" class="data row5 col3" >0.967800</td>
#     </tr>
#     <tr>
#       <th id="T_cde48_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cde48_row6_col0" class="data row6 col0" >2018</td>
#       <td id="T_cde48_row6_col1" class="data row6 col1" >3</td>
#       <td id="T_cde48_row6_col2" class="data row6 col2" >-4.410000</td>
#       <td id="T_cde48_row6_col3" class="data row6 col3" >0.269270</td>
#     </tr>
#     <tr>
#       <th id="T_cde48_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cde48_row7_col0" class="data row7 col0" >2018</td>
#       <td id="T_cde48_row7_col1" class="data row7 col1" >5</td>
#       <td id="T_cde48_row7_col2" class="data row7 col2" >1.190000</td>
#       <td id="T_cde48_row7_col3" class="data row7 col3" >0.791160</td>
#     </tr>
#     <tr>
#       <th id="T_cde48_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cde48_row8_col0" class="data row8 col0" >2018</td>
#       <td id="T_cde48_row8_col1" class="data row8 col1" >10</td>
#       <td id="T_cde48_row8_col2" class="data row8 col2" >8.210000</td>
#       <td id="T_cde48_row8_col3" class="data row8 col3" >0.129310</td>
#     </tr>
#     <tr>
#       <th id="T_cde48_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cde48_row9_col0" class="data row9 col0" >2018</td>
#       <td id="T_cde48_row9_col1" class="data row9 col1" >20</td>
#       <td id="T_cde48_row9_col2" class="data row9 col2" >37.330000</td>
#       <td id="T_cde48_row9_col3" class="data row9 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cde48_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_cde48_row10_col0" class="data row10 col0" >2019</td>
#       <td id="T_cde48_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_cde48_row10_col2" class="data row10 col2" >-3.860000</td>
#       <td id="T_cde48_row10_col3" class="data row10 col3" >0.195740</td>
#     </tr>
#     <tr>
#       <th id="T_cde48_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_cde48_row11_col0" class="data row11 col0" >2019</td>
#       <td id="T_cde48_row11_col1" class="data row11 col1" >3</td>
#       <td id="T_cde48_row11_col2" class="data row11 col2" >8.610000</td>
#       <td id="T_cde48_row11_col3" class="data row11 col3" >0.026840</td>
#     </tr>
#     <tr>
#       <th id="T_cde48_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_cde48_row12_col0" class="data row12 col0" >2019</td>
#       <td id="T_cde48_row12_col1" class="data row12 col1" >5</td>
#       <td id="T_cde48_row12_col2" class="data row12 col2" >1.050000</td>
#       <td id="T_cde48_row12_col3" class="data row12 col3" >0.786880</td>
#     </tr>
#     <tr>
#       <th id="T_cde48_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_cde48_row13_col0" class

# %% [markdown]
# # **FTSE 100**

# %%
import pandas as pd
from tabulate import tabulate

# Initialize an empty list to store results
results = []

days_list = [1, 3, 5, 10, 20]
years_list = range(2017, 2023)  # Years from 2017 to 2022

for year in years_list:
    for days in days_list:
        df = globals()[f'df_{days}_day']  # Dynamically access each DataFrame

        # Ensure 'Date' column is in datetime format
        df['Date'] = pd.to_datetime(df['Date'])
        # Filter for the specific year
        df_filtered = df[df['Date'].dt.year == year]

        y = df_filtered['% FTSE100 Change']
        X = df_filtered[['Change in SWAV',
                         'ADS_Change',
                         'EPU_Change',
                         'Previous % FTSE100 Change',
                         '% MSCI Change',
                         'Vix Close',
                         'Rolling_Avg_Change_in_DCC',
                         'Stringency_Change',
                         'TED'
                         ]]

        X = sm.add_constant(X)
        model = sm.OLS(y, X).fit()

        coef = round(model.params['Change in SWAV'], 2)
        p_value = round(model.pvalues['Change in SWAV'], 5)

        # Append the results to the list with year included
        results.append([year, days, coef, p_value])

# Convert the results list to a DataFrame
results_df = pd.DataFrame(results, columns=['Year', 'Days', 'Change in SWAV', 'P-value'])

# Define a function to apply the styling
def color_rows(row):
    if row['P-value'] < 0.1:
        if row['Change in SWAV'] > 0:
            return ['background-color: green']*len(row)
        elif row['Change in SWAV'] < 0:
            return ['background-color: red']*len(row)
    return ['background-color: grey']*len(row)

# Apply the function to each row of the DataFrame
styled_df = results_df.style.apply(color_rows, axis=1)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_49e8c_row0_col0, #T_49e8c_row0_col1, #T_49e8c_row0_col2, #T_49e8c_row0_col3, #T_49e8c_row1_col0, #T_49e8c_row1_col1, #T_49e8c_row1_col2, #T_49e8c_row1_col3, #T_49e8c_row2_col0, #T_49e8c_row2_col1, #T_49e8c_row2_col2, #T_49e8c_row2_col3, #T_49e8c_row3_col0, #T_49e8c_row3_col1, #T_49e8c_row3_col2, #T_49e8c_row3_col3, #T_49e8c_row4_col0, #T_49e8c_row4_col1, #T_49e8c_row4_col2, #T_49e8c_row4_col3, #T_49e8c_row6_col0, #T_49e8c_row6_col1, #T_49e8c_row6_col2, #T_49e8c_row6_col3, #T_49e8c_row7_col0, #T_49e8c_row7_col1, #T_49e8c_row7_col2, #T_49e8c_row7_col3, #T_49e8c_row9_col0, #T_49e8c_row9_col1, #T_49e8c_row9_col2, #T_49e8c_row9_col3, #T_49e8c_row14_col0, #T_49e8c_row14_col1, #T_49e8c_row14_col2, #T_49e8c_row14_col3, #T_49e8c_row15_col0, #T_49e8c_row15_col1, #T_49e8c_row15_col2, #T_49e8c_row15_col3, #T_49e8c_row16_col0, #T_49e8c_row16_col1, #T_49e8c_row16_col2, #T_49e8c_row16_col3, #T_49e8c_row17_col0, #T_49e8c_row17_col1, #T_49e8c_row17_col2, #T_49e8c_row17_col3, #T_49e8c_row18_col0, #T_49e8c_row18_col1, #T_49e8c_row18_col2, #T_49e8c_row18_col3, #T_49e8c_row20_col0, #T_49e8c_row20_col1, #T_49e8c_row20_col2, #T_49e8c_row20_col3, #T_49e8c_row21_col0, #T_49e8c_row21_col1, #T_49e8c_row21_col2, #T_49e8c_row21_col3, #T_49e8c_row22_col0, #T_49e8c_row22_col1, #T_49e8c_row22_col2, #T_49e8c_row22_col3, #T_49e8c_row24_col0, #T_49e8c_row24_col1, #T_49e8c_row24_col2, #T_49e8c_row24_col3, #T_49e8c_row26_col0, #T_49e8c_row26_col1, #T_49e8c_row26_col2, #T_49e8c_row26_col3, #T_49e8c_row27_col0, #T_49e8c_row27_col1, #T_49e8c_row27_col2, #T_49e8c_row27_col3, #T_49e8c_row28_col0, #T_49e8c_row28_col1, #T_49e8c_row28_col2, #T_49e8c_row28_col3, #T_49e8c_row29_col0, #T_49e8c_row29_col1, #T_49e8c_row29_col2, #T_49e8c_row29_col3 {
#   background-color: grey;
# }
# #T_49e8c_row5_col0, #T_49e8c_row5_col1, #T_49e8c_row5_col2, #T_49e8c_row5_col3, #T_49e8c_row19_col0, #T_49e8c_row19_col1, #T_49e8c_row19_col2, #T_49e8c_row19_col3 {
#   background-color: green;
# }
# #T_49e8c_row8_col0, #T_49e8c_row8_col1, #T_49e8c_row8_col2, #T_49e8c_row8_col3, #T_49e8c_row10_col0, #T_49e8c_row10_col1, #T_49e8c_row10_col2, #T_49e8c_row10_col3, #T_49e8c_row11_col0, #T_49e8c_row11_col1, #T_49e8c_row11_col2, #T_49e8c_row11_col3, #T_49e8c_row12_col0, #T_49e8c_row12_col1, #T_49e8c_row12_col2, #T_49e8c_row12_col3, #T_49e8c_row13_col0, #T_49e8c_row13_col1, #T_49e8c_row13_col2, #T_49e8c_row13_col3, #T_49e8c_row23_col0, #T_49e8c_row23_col1, #T_49e8c_row23_col2, #T_49e8c_row23_col3, #T_49e8c_row25_col0, #T_49e8c_row25_col1, #T_49e8c_row25_col2, #T_49e8c_row25_col3 {
#   background-color: red;
# }
# </style>
# <table id="T_49e8c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49e8c_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_49e8c_level0_col1" class="col_heading level0 col1" >Days</th>
#       <th id="T_49e8c_level0_col2" class="col_heading level0 col2" >Change in SWAV</th>
#       <th id="T_49e8c_level0_col3" class="col_heading level0 col3" >P-value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49e8c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_49e8c_row0_col0" class="data row0 col0" >2017</td>
#       <td id="T_49e8c_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_49e8c_row0_col2" class="data row0 col2" >0.990000</td>
#       <td id="T_49e8c_row0_col3" class="data row0 col3" >0.738240</td>
#     </tr>
#     <tr>
#       <th id="T_49e8c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_49e8c_row1_col0" class="data row1 col0" >2017</td>
#       <td id="T_49e8c_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_49e8c_row1_col2" class="data row1 col2" >-0.670000</td>
#       <td id="T_49e8c_row1_col3" class="data row1 col3" >0.854510</td>
#     </tr>
#     <tr>
#       <th id="T_49e8c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_49e8c_row2_col0" class="data row2 col0" >2017</td>
#       <td id="T_49e8c_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_49e8c_row2_col2" class="data row2 col2" >0.530000</td>
#       <td id="T_49e8c_row2_col3" class="data row2 col3" >0.906240</td>
#     </tr>
#     <tr>
#       <th id="T_49e8c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_49e8c_row3_col0" class="data row3 col0" >2017</td>
#       <td id="T_49e8c_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_49e8c_row3_col2" class="data row3 col2" >6.650000</td>
#       <td id="T_49e8c_row3_col3" class="data row3 col3" >0.162630</td>
#     </tr>
#     <tr>
#       <th id="T_49e8c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_49e8c_row4_col0" class="data row4 col0" >2017</td>
#       <td id="T_49e8c_row4_col1" class="data row4 col1" >20</td>
#       <td id="T_49e8c_row4_col2" class="data row4 col2" >-1.710000</td>
#       <td id="T_49e8c_row4_col3" class="data row4 col3" >0.758310</td>
#     </tr>
#     <tr>
#       <th id="T_49e8c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_49e8c_row5_col0" class="data row5 col0" >2018</td>
#       <td id="T_49e8c_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_49e8c_row5_col2" class="data row5 col2" >5.890000</td>
#       <td id="T_49e8c_row5_col3" class="data row5 col3" >0.089130</td>
#     </tr>
#     <tr>
#       <th id="T_49e8c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_49e8c_row6_col0" class="data row6 col0" >2018</td>
#       <td id="T_49e8c_row6_col1" class="data row6 col1" >3</td>
#       <td id="T_49e8c_row6_col2" class="data row6 col2" >4.570000</td>
#       <td id="T_49e8c_row6_col3" class="data row6 col3" >0.279010</td>
#     </tr>
#     <tr>
#       <th id="T_49e8c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_49e8c_row7_col0" class="data row7 col0" >2018</td>
#       <td id="T_49e8c_row7_col1" class="data row7 col1" >5</td>
#       <td id="T_49e8c_row7_col2" class="data row7 col2" >-3.270000</td>
#       <td id="T_49e8c_row7_col3" class="data row7 col3" >0.471300</td>
#     </tr>
#     <tr>
#       <th id="T_49e8c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_49e8c_row8_col0" class="data row8 col0" >2018</td>
#       <td id="T_49e8c_row8_col1" class="data row8 col1" >10</td>
#       <td id="T_49e8c_row8_col2" class="data row8 col2" >-9.600000</td>
#       <td id="T_49e8c_row8_col3" class="data row8 col3" >0.076740</td>
#     </tr>
#     <tr>
#       <th id="T_49e8c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_49e8c_row9_col0" class="data row9 col0" >2018</td>
#       <td id="T_49e8c_row9_col1" class="data row9 col1" >20</td>
#       <td id="T_49e8c_row9_col2" class="data row9 col2" >-5.590000</td>
#       <td id="T_49e8c_row9_col3" class="data row9 col3" >0.391100</td>
#     </tr>
#     <tr>
#       <th id="T_49e8c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_49e8c_row10_col0" class="data row10 col0" >2019</td>
#       <td id="T_49e8c_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_49e8c_row10_col2" class="data row10 col2" >-5.440000</td>
#       <td id="T_49e8c_row10_col3" class="data row10 col3" >0.091610</td>
#     </tr>
#     <tr>
#       <th id="T_49e8c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_49e8c_row11_col0" class="data row11 col0" >2019</td>
#       <td id="T_49e8c_row11_col1" class="data row11 col1" >3</td>
#       <td id="T_49e8c_row11_col2" class="data row11 col2" >-14.130000</td>
#       <td id="T_49e8c_row11_col3" class="data row11 col3" >0.003530</td>
#     </tr>
#     <tr>
#       <th id="T_49e8c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_49e8c_row12_col0" class="data row12 col0" >2019</td>
#       <td id="T_49e8c_row12_col1" class="data row12 col1" >5</td>
#       <td id="T_49e8c_row12_col2" class="data row12 col2" >-9.400000</td>
#       <td id="T_49e8c_row12_col3" class="data row12 col3" >0.050510</td>
#     </tr>
#     <tr>
#       <th id="T_49e8c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_49e8c_row13_col0" clas

# %% [markdown]
# # **FTSE100 Next**

# %%
import pandas as pd
from tabulate import tabulate

# Initialize an empty list to store results
results = []

days_list = [1, 3, 5, 10, 20]
years_list = range(2017, 2023)  # Years from 2017 to 2022

for year in years_list:
    for days in days_list:
        df = globals()[f'df_{days}_day']  # Dynamically access each DataFrame

        # Ensure 'Date' column is in datetime format
        df['Date'] = pd.to_datetime(df['Date'])
        # Filter for the specific year
        df_filtered = df[df['Date'].dt.year == year]

        y = df_filtered['Next % FTSE100 Change']
        X = df_filtered[['Change in SWAV',
                         'ADS_Change',
                         'EPU_Change',
                         '% FTSE100 Change',
                         'Next % MSCI Change',
                         'Vix Close',
                         'Rolling_Avg_Change_in_DCC',
                         'Stringency_Change']]

        X = sm.add_constant(X)
        model = sm.OLS(y, X).fit()

        coef = round(model.params['Change in SWAV'], 2)
        p_value = round(model.pvalues['Change in SWAV'], 5)

        # Append the results to the list with year included
        results.append([year, days, coef, p_value])

# Convert the results list to a DataFrame
results_df = pd.DataFrame(results, columns=['Year', 'Days', 'Change in SWAV', 'P-value'])

# Define a function to apply the styling
def color_rows(row):
    if row['P-value'] < 0.1:
        if row['Change in SWAV'] > 0:
            return ['background-color: green']*len(row)
        elif row['Change in SWAV'] < 0:
            return ['background-color: red']*len(row)
    return ['background-color: grey']*len(row)

# Apply the function to each row of the DataFrame
styled_df = results_df.style.apply(color_rows, axis=1)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_afbe5_row0_col0, #T_afbe5_row0_col1, #T_afbe5_row0_col2, #T_afbe5_row0_col3, #T_afbe5_row5_col0, #T_afbe5_row5_col1, #T_afbe5_row5_col2, #T_afbe5_row5_col3, #T_afbe5_row6_col0, #T_afbe5_row6_col1, #T_afbe5_row6_col2, #T_afbe5_row6_col3, #T_afbe5_row7_col0, #T_afbe5_row7_col1, #T_afbe5_row7_col2, #T_afbe5_row7_col3, #T_afbe5_row10_col0, #T_afbe5_row10_col1, #T_afbe5_row10_col2, #T_afbe5_row10_col3, #T_afbe5_row11_col0, #T_afbe5_row11_col1, #T_afbe5_row11_col2, #T_afbe5_row11_col3, #T_afbe5_row12_col0, #T_afbe5_row12_col1, #T_afbe5_row12_col2, #T_afbe5_row12_col3, #T_afbe5_row14_col0, #T_afbe5_row14_col1, #T_afbe5_row14_col2, #T_afbe5_row14_col3, #T_afbe5_row15_col0, #T_afbe5_row15_col1, #T_afbe5_row15_col2, #T_afbe5_row15_col3, #T_afbe5_row16_col0, #T_afbe5_row16_col1, #T_afbe5_row16_col2, #T_afbe5_row16_col3, #T_afbe5_row17_col0, #T_afbe5_row17_col1, #T_afbe5_row17_col2, #T_afbe5_row17_col3, #T_afbe5_row20_col0, #T_afbe5_row20_col1, #T_afbe5_row20_col2, #T_afbe5_row20_col3, #T_afbe5_row21_col0, #T_afbe5_row21_col1, #T_afbe5_row21_col2, #T_afbe5_row21_col3, #T_afbe5_row25_col0, #T_afbe5_row25_col1, #T_afbe5_row25_col2, #T_afbe5_row25_col3, #T_afbe5_row26_col0, #T_afbe5_row26_col1, #T_afbe5_row26_col2, #T_afbe5_row26_col3, #T_afbe5_row27_col0, #T_afbe5_row27_col1, #T_afbe5_row27_col2, #T_afbe5_row27_col3, #T_afbe5_row28_col0, #T_afbe5_row28_col1, #T_afbe5_row28_col2, #T_afbe5_row28_col3, #T_afbe5_row29_col0, #T_afbe5_row29_col1, #T_afbe5_row29_col2, #T_afbe5_row29_col3 {
#   background-color: grey;
# }
# #T_afbe5_row1_col0, #T_afbe5_row1_col1, #T_afbe5_row1_col2, #T_afbe5_row1_col3, #T_afbe5_row2_col0, #T_afbe5_row2_col1, #T_afbe5_row2_col2, #T_afbe5_row2_col3, #T_afbe5_row3_col0, #T_afbe5_row3_col1, #T_afbe5_row3_col2, #T_afbe5_row3_col3, #T_afbe5_row4_col0, #T_afbe5_row4_col1, #T_afbe5_row4_col2, #T_afbe5_row4_col3, #T_afbe5_row8_col0, #T_afbe5_row8_col1, #T_afbe5_row8_col2, #T_afbe5_row8_col3, #T_afbe5_row9_col0, #T_afbe5_row9_col1, #T_afbe5_row9_col2, #T_afbe5_row9_col3, #T_afbe5_row13_col0, #T_afbe5_row13_col1, #T_afbe5_row13_col2, #T_afbe5_row13_col3, #T_afbe5_row18_col0, #T_afbe5_row18_col1, #T_afbe5_row18_col2, #T_afbe5_row18_col3, #T_afbe5_row19_col0, #T_afbe5_row19_col1, #T_afbe5_row19_col2, #T_afbe5_row19_col3, #T_afbe5_row22_col0, #T_afbe5_row22_col1, #T_afbe5_row22_col2, #T_afbe5_row22_col3, #T_afbe5_row23_col0, #T_afbe5_row23_col1, #T_afbe5_row23_col2, #T_afbe5_row23_col3, #T_afbe5_row24_col0, #T_afbe5_row24_col1, #T_afbe5_row24_col2, #T_afbe5_row24_col3 {
#   background-color: green;
# }
# </style>
# <table id="T_afbe5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_afbe5_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_afbe5_level0_col1" class="col_heading level0 col1" >Days</th>
#       <th id="T_afbe5_level0_col2" class="col_heading level0 col2" >Change in SWAV</th>
#       <th id="T_afbe5_level0_col3" class="col_heading level0 col3" >P-value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_afbe5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_afbe5_row0_col0" class="data row0 col0" >2017</td>
#       <td id="T_afbe5_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_afbe5_row0_col2" class="data row0 col2" >-2.990000</td>
#       <td id="T_afbe5_row0_col3" class="data row0 col3" >0.301820</td>
#     </tr>
#     <tr>
#       <th id="T_afbe5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_afbe5_row1_col0" class="data row1 col0" >2017</td>
#       <td id="T_afbe5_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_afbe5_row1_col2" class="data row1 col2" >7.180000</td>
#       <td id="T_afbe5_row1_col3" class="data row1 col3" >0.042860</td>
#     </tr>
#     <tr>
#       <th id="T_afbe5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_afbe5_row2_col0" class="data row2 col0" >2017</td>
#       <td id="T_afbe5_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_afbe5_row2_col2" class="data row2 col2" >18.860000</td>
#       <td id="T_afbe5_row2_col3" class="data row2 col3" >0.000010</td>
#     </tr>
#     <tr>
#       <th id="T_afbe5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_afbe5_row3_col0" class="data row3 col0" >2017</td>
#       <td id="T_afbe5_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_afbe5_row3_col2" class="data row3 col2" >15.840000</td>
#       <td id="T_afbe5_row3_col3" class="data row3 col3" >0.000740</td>
#     </tr>
#     <tr>
#       <th id="T_afbe5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_afbe5_row4_col0" class="data row4 col0" >2017</td>
#       <td id="T_afbe5_row4_col1" class="data row4 col1" >20</td>
#       <td id="T_afbe5_row4_col2" class="data row4 col2" >36.330000</td>
#       <td id="T_afbe5_row4_col3" class="data row4 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_afbe5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_afbe5_row5_col0" class="data row5 col0" >2018</td>
#       <td id="T_afbe5_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_afbe5_row5_col2" class="data row5 col2" >-3.130000</td>
#       <td id="T_afbe5_row5_col3" class="data row5 col3" >0.350500</td>
#     </tr>
#     <tr>
#       <th id="T_afbe5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_afbe5_row6_col0" class="data row6 col0" >2018</td>
#       <td id="T_afbe5_row6_col1" class="data row6 col1" >3</td>
#       <td id="T_afbe5_row6_col2" class="data row6 col2" >-2.820000</td>
#       <td id="T_afbe5_row6_col3" class="data row6 col3" >0.512870</td>
#     </tr>
#     <tr>
#       <th id="T_afbe5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_afbe5_row7_col0" class="data row7 col0" >2018</td>
#       <td id="T_afbe5_row7_col1" class="data row7 col1" >5</td>
#       <td id="T_afbe5_row7_col2" class="data row7 col2" >0.930000</td>
#       <td id="T_afbe5_row7_col3" class="data row7 col3" >0.851710</td>
#     </tr>
#     <tr>
#       <th id="T_afbe5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_afbe5_row8_col0" class="data row8 col0" >2018</td>
#       <td id="T_afbe5_row8_col1" class="data row8 col1" >10</td>
#       <td id="T_afbe5_row8_col2" class="data row8 col2" >13.110000</td>
#       <td id="T_afbe5_row8_col3" class="data row8 col3" >0.043650</td>
#     </tr>
#     <tr>
#       <th id="T_afbe5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_afbe5_row9_col0" class="data row9 col0" >2018</td>
#       <td id="T_afbe5_row9_col1" class="data row9 col1" >20</td>
#       <td id="T_afbe5_row9_col2" class="data row9 col2" >32.950000</td>
#       <td id="T_afbe5_row9_col3" class="data row9 col3" >0.000020</td>
#     </tr>
#     <tr>
#       <th id="T_afbe5_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_afbe5_row10_col0" class="data row10 col0" >2019</td>
#       <td id="T_afbe5_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_afbe5_row10_col2" class="data row10 col2" >-4.010000</td>
#       <td id="T_afbe5_row10_col3" class="data row10 col3" >0.219090</td>
#     </tr>
#     <tr>
#       <th id="T_afbe5_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_afbe5_row11_col0" class="data row11 col0" >2019</td>
#       <td id="T_afbe5_row11_col1" class="data row11 col1" >3</td>
#       <td id="T_afbe5_row11_col2" class="data row11 col2" >0.010000</td>
#       <td id="T_afbe5_row11_col3" class="data row11 col3" >0.998440</td>
#     </tr>
#     <tr>
#       <th id="T_afbe5_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_afbe5_row12_col0" class="data row12 col0" >2019</td>
#       <td id="T_afbe5_row12_col1" class="data row12 col1" >5</td>
#       <td id="T_afbe5_row12_col2" class="data row12 col2" >0.850000</td>
#       <td id="T_afbe5_row12_col3" class="data row12 col3" >0.854620</td>
#     </tr>
#     <tr>
#       <th id="T_afbe5_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_afbe5_row13_col0" class="data row13 col0" >2019</t

# %% [markdown]
# # **FTSE 250**

# %%
import pandas as pd
from tabulate import tabulate

# Initialize an empty list to store results
results = []

days_list = [1, 3, 5, 10, 20]
years_list = range(2017, 2023)  # Years from 2017 to 2022

for year in years_list:
    for days in days_list:
        df = globals()[f'df_{days}_day']  # Dynamically access each DataFrame

        # Ensure 'Date' column is in datetime format
        df['Date'] = pd.to_datetime(df['Date'])
        # Filter for the specific year
        df_filtered = df[df['Date'].dt.year == year]

        y = df_filtered['% FTSE250 Change']
        X = df_filtered[['Change in SWAV',
                         'ADS_Change',
                         'EPU_Change',
                         'Previous % FTSE250 Change',
                         '% MSCI Change',
                         'Vix Close',
                         'Rolling_Avg_Change_in_DCC',
                         'Stringency_Change']]

        X = sm.add_constant(X)
        model = sm.OLS(y, X).fit()

        coef = round(model.params['Change in SWAV'], 2)
        p_value = round(model.pvalues['Change in SWAV'], 5)

        # Append the results to the list with year included
        results.append([year, days, coef, p_value])

# Convert the results list to a DataFrame
results_df = pd.DataFrame(results, columns=['Year', 'Days', 'Change in SWAV', 'P-value'])

# Define a function to apply the styling
def color_rows(row):
    if row['P-value'] < 0.1:
        if row['Change in SWAV'] > 0:
            return ['background-color: green']*len(row)
        elif row['Change in SWAV'] < 0:
            return ['background-color: red']*len(row)
    return ['background-color: grey']*len(row)

# Apply the function to each row of the DataFrame
styled_df = results_df.style.apply(color_rows, axis=1)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_79302_row0_col0, #T_79302_row0_col1, #T_79302_row0_col2, #T_79302_row0_col3, #T_79302_row1_col0, #T_79302_row1_col1, #T_79302_row1_col2, #T_79302_row1_col3, #T_79302_row2_col0, #T_79302_row2_col1, #T_79302_row2_col2, #T_79302_row2_col3, #T_79302_row3_col0, #T_79302_row3_col1, #T_79302_row3_col2, #T_79302_row3_col3, #T_79302_row7_col0, #T_79302_row7_col1, #T_79302_row7_col2, #T_79302_row7_col3, #T_79302_row8_col0, #T_79302_row8_col1, #T_79302_row8_col2, #T_79302_row8_col3, #T_79302_row10_col0, #T_79302_row10_col1, #T_79302_row10_col2, #T_79302_row10_col3, #T_79302_row12_col0, #T_79302_row12_col1, #T_79302_row12_col2, #T_79302_row12_col3, #T_79302_row15_col0, #T_79302_row15_col1, #T_79302_row15_col2, #T_79302_row15_col3, #T_79302_row16_col0, #T_79302_row16_col1, #T_79302_row16_col2, #T_79302_row16_col3, #T_79302_row17_col0, #T_79302_row17_col1, #T_79302_row17_col2, #T_79302_row17_col3, #T_79302_row18_col0, #T_79302_row18_col1, #T_79302_row18_col2, #T_79302_row18_col3, #T_79302_row20_col0, #T_79302_row20_col1, #T_79302_row20_col2, #T_79302_row20_col3, #T_79302_row21_col0, #T_79302_row21_col1, #T_79302_row21_col2, #T_79302_row21_col3, #T_79302_row22_col0, #T_79302_row22_col1, #T_79302_row22_col2, #T_79302_row22_col3, #T_79302_row23_col0, #T_79302_row23_col1, #T_79302_row23_col2, #T_79302_row23_col3, #T_79302_row26_col0, #T_79302_row26_col1, #T_79302_row26_col2, #T_79302_row26_col3, #T_79302_row27_col0, #T_79302_row27_col1, #T_79302_row27_col2, #T_79302_row27_col3, #T_79302_row28_col0, #T_79302_row28_col1, #T_79302_row28_col2, #T_79302_row28_col3, #T_79302_row29_col0, #T_79302_row29_col1, #T_79302_row29_col2, #T_79302_row29_col3 {
#   background-color: grey;
# }
# #T_79302_row4_col0, #T_79302_row4_col1, #T_79302_row4_col2, #T_79302_row4_col3, #T_79302_row5_col0, #T_79302_row5_col1, #T_79302_row5_col2, #T_79302_row5_col3, #T_79302_row6_col0, #T_79302_row6_col1, #T_79302_row6_col2, #T_79302_row6_col3, #T_79302_row9_col0, #T_79302_row9_col1, #T_79302_row9_col2, #T_79302_row9_col3, #T_79302_row19_col0, #T_79302_row19_col1, #T_79302_row19_col2, #T_79302_row19_col3, #T_79302_row24_col0, #T_79302_row24_col1, #T_79302_row24_col2, #T_79302_row24_col3 {
#   background-color: green;
# }
# #T_79302_row11_col0, #T_79302_row11_col1, #T_79302_row11_col2, #T_79302_row11_col3, #T_79302_row13_col0, #T_79302_row13_col1, #T_79302_row13_col2, #T_79302_row13_col3, #T_79302_row14_col0, #T_79302_row14_col1, #T_79302_row14_col2, #T_79302_row14_col3, #T_79302_row25_col0, #T_79302_row25_col1, #T_79302_row25_col2, #T_79302_row25_col3 {
#   background-color: red;
# }
# </style>
# <table id="T_79302" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_79302_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_79302_level0_col1" class="col_heading level0 col1" >Days</th>
#       <th id="T_79302_level0_col2" class="col_heading level0 col2" >Change in SWAV</th>
#       <th id="T_79302_level0_col3" class="col_heading level0 col3" >P-value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79302_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_79302_row0_col0" class="data row0 col0" >2017</td>
#       <td id="T_79302_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_79302_row0_col2" class="data row0 col2" >-1.620000</td>
#       <td id="T_79302_row0_col3" class="data row0 col3" >0.546320</td>
#     </tr>
#     <tr>
#       <th id="T_79302_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_79302_row1_col0" class="data row1 col0" >2017</td>
#       <td id="T_79302_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_79302_row1_col2" class="data row1 col2" >-1.350000</td>
#       <td id="T_79302_row1_col3" class="data row1 col3" >0.676460</td>
#     </tr>
#     <tr>
#       <th id="T_79302_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_79302_row2_col0" class="data row2 col0" >2017</td>
#       <td id="T_79302_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_79302_row2_col2" class="data row2 col2" >1.490000</td>
#       <td id="T_79302_row2_col3" class="data row2 col3" >0.729090</td>
#     </tr>
#     <tr>
#       <th id="T_79302_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_79302_row3_col0" class="data row3 col0" >2017</td>
#       <td id="T_79302_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_79302_row3_col2" class="data row3 col2" >4.200000</td>
#       <td id="T_79302_row3_col3" class="data row3 col3" >0.374100</td>
#     </tr>
#     <tr>
#       <th id="T_79302_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_79302_row4_col0" class="data row4 col0" >2017</td>
#       <td id="T_79302_row4_col1" class="data row4 col1" >20</td>
#       <td id="T_79302_row4_col2" class="data row4 col2" >16.150000</td>
#       <td id="T_79302_row4_col3" class="data row4 col3" >0.001490</td>
#     </tr>
#     <tr>
#       <th id="T_79302_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_79302_row5_col0" class="data row5 col0" >2018</td>
#       <td id="T_79302_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_79302_row5_col2" class="data row5 col2" >6.270000</td>
#       <td id="T_79302_row5_col3" class="data row5 col3" >0.051540</td>
#     </tr>
#     <tr>
#       <th id="T_79302_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_79302_row6_col0" class="data row6 col0" >2018</td>
#       <td id="T_79302_row6_col1" class="data row6 col1" >3</td>
#       <td id="T_79302_row6_col2" class="data row6 col2" >7.410000</td>
#       <td id="T_79302_row6_col3" class="data row6 col3" >0.064620</td>
#     </tr>
#     <tr>
#       <th id="T_79302_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_79302_row7_col0" class="data row7 col0" >2018</td>
#       <td id="T_79302_row7_col1" class="data row7 col1" >5</td>
#       <td id="T_79302_row7_col2" class="data row7 col2" >0.370000</td>
#       <td id="T_79302_row7_col3" class="data row7 col3" >0.932140</td>
#     </tr>
#     <tr>
#       <th id="T_79302_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_79302_row8_col0" class="data row8 col0" >2018</td>
#       <td id="T_79302_row8_col1" class="data row8 col1" >10</td>
#       <td id="T_79302_row8_col2" class="data row8 col2" >-8.400000</td>
#       <td id="T_79302_row8_col3" class="data row8 col3" >0.121480</td>
#     </tr>
#     <tr>
#       <th id="T_79302_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_79302_row9_col0" class="data row9 col0" >2018</td>
#       <td id="T_79302_row9_col1" class="data row9 col1" >20</td>
#       <td id="T_79302_row9_col2" class="data row9 col2" >11.270000</td>
#       <td id="T_79302_row9_col3" class="data row9 col3" >0.090880</td>
#     </tr>
#     <tr>
#       <th id="T_79302_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_79302_row10_col0" class="data row10 col0" >2019</td>
#       <td id="T_79302_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_79302_row10_col2" class="data row10 col2" >-2.060000</td>
#       <td id="T_79302_row10_col3" class="data row10 col3" >0.531450</td>
#     </tr>
#     <tr>
#       <th id="T_79302_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_79302_row11_col0" class="data row11 col0" >2019</td>
#       <td id="T_79302_row11_col1" class="data row11 col1" >3</td>
#       <td id="T_79302_row11_col2" class="data row11 col2" >-9.230000</td>
#       <td id="T_79302_row11_col3" class="data row11 col3" >0.031310</td>
#     </tr>
#     <tr>
#       <th id="T_79302_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_79302_row12_col0" class="data row12 col0" >2019</td>
#       <td id="T_79302_row12_col1" class="data row12 col1" >5</td>
#       <td id="T_79302_row12_col2" class="data row12 col2" >-2.220000</td>
#       <td id="T_79302_row12_col3" class="data row12 col3" >0.603510</td>
#     </tr>
#     <tr>
#       <th id="T_79302_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_79302_row13_col0" class

# %% [markdown]
# # **Next FTSE 250**

# %%
import pandas as pd
from tabulate import tabulate

# Initialize an empty list to store results
results = []

days_list = [1, 3, 5, 10, 20]
years_list = range(2017, 2023)  # Years from 2017 to 2022

for year in years_list:
    for days in days_list:
        df = globals()[f'df_{days}_day']  # Dynamically access each DataFrame

        # Ensure 'Date' column is in datetime format
        df['Date'] = pd.to_datetime(df['Date'])
        # Filter for the specific year
        df_filtered = df[df['Date'].dt.year == year]

        y = df_filtered['Next % FTSE250 Change']
        X = df_filtered[['Change in SWAV',
                         'ADS_Change',
                         'EPU_Change',
                         '% FTSE250 Change',
                         'Next % MSCI Change',
                         'Vix Close',
                         'Rolling_Avg_Change_in_DCC',
                         'Stringency_Change']]

        X = sm.add_constant(X)
        model = sm.OLS(y, X).fit()

        coef = round(model.params['Change in SWAV'], 2)
        p_value = round(model.pvalues['Change in SWAV'], 5)

        # Append the results to the list with year included
        results.append([year, days, coef, p_value])

# Convert the results list to a DataFrame
results_df = pd.DataFrame(results, columns=['Year', 'Days', 'Change in SWAV', 'P-value'])

# Define a function to apply the styling
def color_rows(row):
    if row['P-value'] < 0.1:
        if row['Change in SWAV'] > 0:
            return ['background-color: green']*len(row)
        elif row['Change in SWAV'] < 0:
            return ['background-color: red']*len(row)
    return ['background-color: grey']*len(row)

# Apply the function to each row of the DataFrame
styled_df = results_df.style.apply(color_rows, axis=1)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_599dc_row0_col0, #T_599dc_row0_col1, #T_599dc_row0_col2, #T_599dc_row0_col3, #T_599dc_row5_col0, #T_599dc_row5_col1, #T_599dc_row5_col2, #T_599dc_row5_col3, #T_599dc_row6_col0, #T_599dc_row6_col1, #T_599dc_row6_col2, #T_599dc_row6_col3, #T_599dc_row7_col0, #T_599dc_row7_col1, #T_599dc_row7_col2, #T_599dc_row7_col3, #T_599dc_row10_col0, #T_599dc_row10_col1, #T_599dc_row10_col2, #T_599dc_row10_col3, #T_599dc_row11_col0, #T_599dc_row11_col1, #T_599dc_row11_col2, #T_599dc_row11_col3, #T_599dc_row12_col0, #T_599dc_row12_col1, #T_599dc_row12_col2, #T_599dc_row12_col3, #T_599dc_row14_col0, #T_599dc_row14_col1, #T_599dc_row14_col2, #T_599dc_row14_col3, #T_599dc_row15_col0, #T_599dc_row15_col1, #T_599dc_row15_col2, #T_599dc_row15_col3, #T_599dc_row16_col0, #T_599dc_row16_col1, #T_599dc_row16_col2, #T_599dc_row16_col3, #T_599dc_row17_col0, #T_599dc_row17_col1, #T_599dc_row17_col2, #T_599dc_row17_col3, #T_599dc_row18_col0, #T_599dc_row18_col1, #T_599dc_row18_col2, #T_599dc_row18_col3, #T_599dc_row20_col0, #T_599dc_row20_col1, #T_599dc_row20_col2, #T_599dc_row20_col3, #T_599dc_row21_col0, #T_599dc_row21_col1, #T_599dc_row21_col2, #T_599dc_row21_col3, #T_599dc_row23_col0, #T_599dc_row23_col1, #T_599dc_row23_col2, #T_599dc_row23_col3, #T_599dc_row24_col0, #T_599dc_row24_col1, #T_599dc_row24_col2, #T_599dc_row24_col3, #T_599dc_row25_col0, #T_599dc_row25_col1, #T_599dc_row25_col2, #T_599dc_row25_col3, #T_599dc_row26_col0, #T_599dc_row26_col1, #T_599dc_row26_col2, #T_599dc_row26_col3, #T_599dc_row28_col0, #T_599dc_row28_col1, #T_599dc_row28_col2, #T_599dc_row28_col3, #T_599dc_row29_col0, #T_599dc_row29_col1, #T_599dc_row29_col2, #T_599dc_row29_col3 {
#   background-color: grey;
# }
# #T_599dc_row1_col0, #T_599dc_row1_col1, #T_599dc_row1_col2, #T_599dc_row1_col3, #T_599dc_row2_col0, #T_599dc_row2_col1, #T_599dc_row2_col2, #T_599dc_row2_col3, #T_599dc_row3_col0, #T_599dc_row3_col1, #T_599dc_row3_col2, #T_599dc_row3_col3, #T_599dc_row4_col0, #T_599dc_row4_col1, #T_599dc_row4_col2, #T_599dc_row4_col3, #T_599dc_row8_col0, #T_599dc_row8_col1, #T_599dc_row8_col2, #T_599dc_row8_col3, #T_599dc_row9_col0, #T_599dc_row9_col1, #T_599dc_row9_col2, #T_599dc_row9_col3, #T_599dc_row19_col0, #T_599dc_row19_col1, #T_599dc_row19_col2, #T_599dc_row19_col3, #T_599dc_row22_col0, #T_599dc_row22_col1, #T_599dc_row22_col2, #T_599dc_row22_col3 {
#   background-color: green;
# }
# #T_599dc_row13_col0, #T_599dc_row13_col1, #T_599dc_row13_col2, #T_599dc_row13_col3, #T_599dc_row27_col0, #T_599dc_row27_col1, #T_599dc_row27_col2, #T_599dc_row27_col3 {
#   background-color: red;
# }
# </style>
# <table id="T_599dc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_599dc_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_599dc_level0_col1" class="col_heading level0 col1" >Days</th>
#       <th id="T_599dc_level0_col2" class="col_heading level0 col2" >Change in SWAV</th>
#       <th id="T_599dc_level0_col3" class="col_heading level0 col3" >P-value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_599dc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_599dc_row0_col0" class="data row0 col0" >2017</td>
#       <td id="T_599dc_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_599dc_row0_col2" class="data row0 col2" >-0.690000</td>
#       <td id="T_599dc_row0_col3" class="data row0 col3" >0.796200</td>
#     </tr>
#     <tr>
#       <th id="T_599dc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_599dc_row1_col0" class="data row1 col0" >2017</td>
#       <td id="T_599dc_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_599dc_row1_col2" class="data row1 col2" >6.760000</td>
#       <td id="T_599dc_row1_col3" class="data row1 col3" >0.032880</td>
#     </tr>
#     <tr>
#       <th id="T_599dc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_599dc_row2_col0" class="data row2 col0" >2017</td>
#       <td id="T_599dc_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_599dc_row2_col2" class="data row2 col2" >10.720000</td>
#       <td id="T_599dc_row2_col3" class="data row2 col3" >0.011510</td>
#     </tr>
#     <tr>
#       <th id="T_599dc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_599dc_row3_col0" class="data row3 col0" >2017</td>
#       <td id="T_599dc_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_599dc_row3_col2" class="data row3 col2" >9.880000</td>
#       <td id="T_599dc_row3_col3" class="data row3 col3" >0.027560</td>
#     </tr>
#     <tr>
#       <th id="T_599dc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_599dc_row4_col0" class="data row4 col0" >2017</td>
#       <td id="T_599dc_row4_col1" class="data row4 col1" >20</td>
#       <td id="T_599dc_row4_col2" class="data row4 col2" >21.540000</td>
#       <td id="T_599dc_row4_col3" class="data row4 col3" >0.000010</td>
#     </tr>
#     <tr>
#       <th id="T_599dc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_599dc_row5_col0" class="data row5 col0" >2018</td>
#       <td id="T_599dc_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_599dc_row5_col2" class="data row5 col2" >-2.430000</td>
#       <td id="T_599dc_row5_col3" class="data row5 col3" >0.424370</td>
#     </tr>
#     <tr>
#       <th id="T_599dc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_599dc_row6_col0" class="data row6 col0" >2018</td>
#       <td id="T_599dc_row6_col1" class="data row6 col1" >3</td>
#       <td id="T_599dc_row6_col2" class="data row6 col2" >-4.930000</td>
#       <td id="T_599dc_row6_col3" class="data row6 col3" >0.211210</td>
#     </tr>
#     <tr>
#       <th id="T_599dc_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_599dc_row7_col0" class="data row7 col0" >2018</td>
#       <td id="T_599dc_row7_col1" class="data row7 col1" >5</td>
#       <td id="T_599dc_row7_col2" class="data row7 col2" >0.200000</td>
#       <td id="T_599dc_row7_col3" class="data row7 col3" >0.965790</td>
#     </tr>
#     <tr>
#       <th id="T_599dc_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_599dc_row8_col0" class="data row8 col0" >2018</td>
#       <td id="T_599dc_row8_col1" class="data row8 col1" >10</td>
#       <td id="T_599dc_row8_col2" class="data row8 col2" >17.570000</td>
#       <td id="T_599dc_row8_col3" class="data row8 col3" >0.001360</td>
#     </tr>
#     <tr>
#       <th id="T_599dc_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_599dc_row9_col0" class="data row9 col0" >2018</td>
#       <td id="T_599dc_row9_col1" class="data row9 col1" >20</td>
#       <td id="T_599dc_row9_col2" class="data row9 col2" >36.410000</td>
#       <td id="T_599dc_row9_col3" class="data row9 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_599dc_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_599dc_row10_col0" class="data row10 col0" >2019</td>
#       <td id="T_599dc_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_599dc_row10_col2" class="data row10 col2" >-2.970000</td>
#       <td id="T_599dc_row10_col3" class="data row10 col3" >0.367990</td>
#     </tr>
#     <tr>
#       <th id="T_599dc_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_599dc_row11_col0" class="data row11 col0" >2019</td>
#       <td id="T_599dc_row11_col1" class="data row11 col1" >3</td>
#       <td id="T_599dc_row11_col2" class="data row11 col2" >2.850000</td>
#       <td id="T_599dc_row11_col3" class="data row11 col3" >0.508440</td>
#     </tr>
#     <tr>
#       <th id="T_599dc_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_599dc_row12_col0" class="data row12 col0" >2019</td>
#       <td id="T_599dc_row12_col1" class="data row12 col1" >5</td>
#       <td id="T_599dc_row12_col2" class="data row12 col2" >-3.460000</td>
#       <td id="T_599dc_row12_col3" class="data row12 col3" >0.402950</td>
#     </tr>
#     <tr>
#       <th id="T_599dc_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_599dc_row13_col0" clas
