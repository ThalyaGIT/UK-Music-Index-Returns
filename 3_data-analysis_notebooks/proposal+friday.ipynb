# %% [markdown]
# <a href="https://colab.research.google.com/github/ThalyaGIT/UK-Music-Index-Returns/blob/main/3_data-analysis_notebooks/proposal%2Bfriday.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Introduction and Background**
# **Objective:** Explore the relationship between Changes in Spotify UK Top 200 songs SWAV (Streamed Weighted Average Valence), a sentiment measure derived from music streaming data, and the returns of major UK market indices (FTSE 100, FTSE 250, and FTSE Small Cap).
#
# **Context:** Based on Edmans' global study, which identified a positive relationship between sentiment and global index returns.
#
# **Focus:** Determine whether similar sentiment-market return patterns exist within the UK, with a particular emphasis on how sentiment influences market behavior.

# %%
# @title
# Import packages
import pandas as pd
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from tabulate import tabulate
from scipy import stats
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy.stats.mstats import winsorize
from scipy.stats import zscore

# Open CSVs into dataframe
# url_1_day = 'https://raw.githubusercontent.com/ThalyaGIT/UK-Music-Index-Returns/Fridays_only/0-data-gold/data_1_days.csv'
# url_3_day = 'https://raw.githubusercontent.com/ThalyaGIT/UK-Music-Index-Returns/Fridays_only/0-data-gold/data_3_days.csv'
url_5_day = 'https://raw.githubusercontent.com/ThalyaGIT/UK-Music-Index-Returns/Fridays_only/0-data-gold/data_1_days.csv'
url_10_day = 'https://raw.githubusercontent.com/ThalyaGIT/UK-Music-Index-Returns/Fridays_only/0-data-gold/data_2_days.csv'
# url_10_day = 'https://raw.githubusercontent.com/ThalyaGIT/UK-Music-Index-Returns/Fridays_only/0-data-gold/data_10_days.csv'
# url_20_day = 'https://raw.githubusercontent.com/ThalyaGIT/UK-Music-Index-Returns/Fridays_only/0-data-gold/data_20_days.csv'

df_1_day = pd.read_csv(url_1_day)
df_3_day = pd.read_csv(url_3_day)
df_5_day = pd.read_csv(url_5_day)
df_10_day = pd.read_csv(url_10_day)
df_20_day = pd.read_csv(url_20_day)


# Open CSV into dataframe with TED
# url_1_day_TED = 'https://raw.githubusercontent.com/ThalyaGIT/UK-Music-Index-Returns/Fridays_only/0-data-gold/data_1_days_TED.csv'
# url_3_day_TED = 'https://raw.githubusercontent.com/ThalyaGIT/UK-Music-Index-Returns/Fridays_only/0-data-gold/data_3_days_TED.csv'
url_5_day_TED = 'https://raw.githubusercontent.com/ThalyaGIT/UK-Music-Index-Returns/Fridays_only/0-data-gold/data_1_days_TED.csv'
url_10_day_TED = 'https://raw.githubusercontent.com/ThalyaGIT/UK-Music-Index-Returns/Fridays_only/0-data-gold/data_2_days_TED.csv'
# url_10_day_TED = 'https://raw.githubusercontent.com/ThalyaGIT/UK-Music-Index-Returns/Fridays_only/0-data-gold/data_10_days_TED.csv'
# url_20_day_TED = 'https://raw.githubusercontent.com/ThalyaGIT/UK-Music-Index-Returns/Fridays_only/0-data-gold/data_20_days_TED.csv'

# df_1_day_TED = pd.read_csv(url_1_day_TED)
# df_3_day_TED = pd.read_csv(url_3_day_TED)
df_5_day_TED = pd.read_csv(url_5_day_TED)
df_10_day_TED = pd.read_csv(url_10_day_TED)
# df_20_day_TED = pd.read_csv(url_20_day_TED)

# %% [markdown]
# # **Initial Analysis: SWAV and FTSE Indices**
#
# The initial regression analysis shows a significant ***negative relationship*** between changes in SWAV and FTSE 100 returns, which contrasts with the global positive relationship found by Edmans.
#
# This could indicate that the FTSE 100 is perceived differently within the UK context. The global ownership of FTSE 100 holdings may introduce additional noise into the relationship, potentially influencing the results. These findings suggest a need for further investigation to understand the underlying dynamics.

# %%
# @title
# Initialize an empty list to store results
results = []
model_summaries = []  # Store model summaries to print later

indices = ['FTSE100', 'FTSE250', 'FTSESmallCap']
days_list = [5]

for days in days_list:
    result_row = [days]  # Start the row with the number of days
    for index in indices:
        df = globals()[f'df_{days}_day']  # Dynamically access each DataFrame

        # Ensure 'Date' column is in datetime format
        df['Date'] = pd.to_datetime(df['Date'])

        # Extract the month from the 'Date' column
        df['Month'] = df['Date'].dt.month
        df['Day'] = df['Date'].dt.day

        # Define the dependent variable
        y = df[f'% {index} Change']

        # Define the independent variables
        X = df[['Change in SWAV',
                'ADS_Change',
                'EPU_Change',
                f'Previous % {index} Change',
                '% MSCI Change',
                'Vix Close',
                'Rolling_Avg_Change_in_DCC']]

        # Convert all columns to numeric, coercing errors to NaN
        X = X.apply(pd.to_numeric, errors='coerce')
        y = pd.to_numeric(y, errors='coerce')

        # Drop rows with any NaN values
        X = X.dropna()
        y = y.loc[X.index]  # Ensure 'y' aligns with 'X' after dropping NaNs

        # Ensure that both X and y are aligned and are purely numeric
        if X.shape[0] > 0 and y.shape[0] > 0:  # Proceed only if there's valid data
            # Add a constant term to the model
            X = sm.add_constant(X)

            # Fit the model
            model = sm.OLS(y, X).fit()

            # Extract the coefficient and p-value for 'Change in SWAV'
            coef = round(model.params['Change in SWAV'], 2)
            p_value = round(model.pvalues['Change in SWAV'], 5)

            # Store the coefficient and p-value as a tuple
            result_row.append((coef, p_value))

            # Store the model summary to print later if significant
            if p_value < 0.1:
                model_summaries.append((index, days, model.summary()))

        else:
            result_row.append((None, None))  # Store None for both if no valid data

    # Append the result row for this combination of days
    results.append(result_row)

# Define column names dynamically, ensuring "Days" is the first column
columns = ['Business Days']
for index in indices:
    columns.extend([f'SWAV Change on {index} Change'])

# Convert the results list to a DataFrame, extracting only the coefficients
results_df = pd.DataFrame([[row[0]] + [r[0] if isinstance(r, tuple) else None for r in row[1:]] for row in results], columns=columns)

# Define a function to apply the styling based on significance
def color_rows(row, original_results):
    colors = []
    for i in range(1, len(row)):  # Skip Days, then iterate through Coefs
        # Safely access the original tuple
        item = original_results[row.name][i]
        if isinstance(item, tuple):
            coef, p_value = item
            if coef is not None and p_value < 0.1:  # Only color if p-value < 0.1 (significant)
                if coef > 0:
                    colors.append('background-color: lightgreen')
                elif coef < 0:
                    colors.append('background-color: lightpink')
                else:
                    colors.append('')
            else:
                colors.append('')  # No color for non-significant or None
        else:
            colors.append('')  # No color if item is not a tuple
    return [''] * 1 + colors  # No coloring for Days

# Apply the function to each row of the DataFrame, passing the original results
styled_df = results_df.style.apply(color_rows, axis=1, original_results=results)

# Display the styled DataFrame (in Jupyter or similar environments)
box_message = (
    "--------------------------------------------\n"
    "| Coefficients of 'Change in SWAV' by index |\n"
    "|                                           |\n"
    "| Light green: Significant positive (10%)   |\n"
    "| Light pink: Significant negative (10%)    |\n"
    "--------------------------------------------\n"
)

print(box_message)
display(styled_df)

# Print all the stored model summaries after displaying the styled DataFrame
for index, days, summary in model_summaries:
    print(f"\n\033[1mModel Summary for {index} at {days} days:\033[0m")
    print(summary)
# Out:
# --------------------------------------------
# | Coefficients of 'Change in SWAV' by index |
# |                                           |
# | Light green: Significant positive (10%)   |
# | Light pink: Significant negative (10%)    |
# --------------------------------------------
# /usr/local/lib/python3.10/dist-packages/statsmodels/regression/linear_model.py:1967: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# <style type="text/css">
# #T_4e6be_row0_col1 {
#   background-color: lightpink;
# }
# </style>
# <table id="T_4e6be" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e6be_level0_col0" class="col_heading level0 col0" >Business Days</th>
#       <th id="T_4e6be_level0_col1" class="col_heading level0 col1" >SWAV Change on FTSE100 Change</th>
#       <th id="T_4e6be_level0_col2" class="col_heading level0 col2" >SWAV Change on FTSE250 Change</th>
#       <th id="T_4e6be_level0_col3" class="col_heading level0 col3" >SWAV Change on FTSESmallCap Change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e6be_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4e6be_row0_col0" class="data row0 col0" >5</td>
#       <td id="T_4e6be_row0_col1" class="data row0 col1" >-6.380000</td>
#       <td id="T_4e6be_row0_col2" class="data row0 col2" >-1.670000</td>
#       <td id="T_4e6be_row0_col3" class="data row0 col3" >3.760000</td>
#     </tr>
#   </tbody>
# </table>
# Model Summary for FTSE100 at 5 days:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       % FTSE100 Change   R-squared:                       0.572
# Model:                            OLS   Adj. R-squared:                  0.564
# Method:                 Least Squares   F-statistic:                     76.08
# Date:                Sat, 07 Sep 2024   Prob (F-statistic):           5.28e-60
# Time:                        11:26:23   Log-Likelihood:                -623.12
# No. Observations:                 349   AIC:                             1260.
# Df Residuals:                     342   BIC:                             1287.
# Df Model:                           6
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         0.1585      0.217      0.729      0.466      -0.269       0.586
# Change in SWAV               -6.3836      3.527     -1.810      0.071     -13.321       0.554
# ADS_Change                    0.1148      0.073      1.567      0.118      -0.029       0.259
# EPU_Change                   -0.0009      0.001     -1.491      0.137      -0.002       0.000
# Previous % FTSE100 Change    -0.0743      0.037     -1.990      0.047      -0.148      -0.001
# % MSCI Change                 0.6414      0.033     19.396      0.000       0.576       0.706
# Vix Close                    -0.0125      0.011     -1.169      0.243      -0.033       0.008
# Rolling_Avg_Change_in_DCC          0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       38.526   Durbin-Watson:                   2.098
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              220.180
# Skew:                          -0.127   Prob(JB):                     1.54e-48
# Kurtosis:                       6.883   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# # **Exploratory Analysis: Seasonal Extremes in SWAV**
# During exploratory analysis, I found extreme changes in SWAV in December and January, likely due to Christmas music. I will show the distribution of SWAV and its changes across months to illustrate this festive impact on sentiment data.

# %%
# @title
# Ensure 'Date' column is in datetime format
df_5_day['Date'] = pd.to_datetime(df_5_day['Date'])

# Extract the month from the 'Date' column
df_5_day['Month'] = df_5_day['Date'].dt.month

# Calculate the average 'SWAV' by month
monthly_avg = df_5_day.groupby('Month')['SWAV'].mean()

# Plot the average 'SWAV' by month
plt.figure(figsize=(10, 6))

# Assign colors, with December as a pinkish color
colors = ['skyblue'] * 11 + ['lightcoral']  # 'lightcoral' is a pinkish color

monthly_avg.plot(kind='bar', color=colors)
plt.title('Average SWAV by Month', fontsize=12, fontweight='bold', ha='center')
plt.xlabel('Month')
plt.ylabel('Average SWAV')
plt.xticks(ticks=range(12), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.ylim(0.45)  # Set the y-axis to start at 0.45
plt.show()

# %%
# @title
# Calculate the average 'Change in SWAV' by month
monthly_avg = df_5_day.groupby('Month')['Change in SWAV'].mean()

# Plot the average 'Change in SWAV' by month
plt.figure(figsize=(10, 6))

# Assign colors, with January and December as light coral
colors = ['lightcoral'] + ['skyblue'] * 10 + ['lightcoral']

monthly_avg.plot(kind='bar', color=colors)
plt.title('Average Change in SWAV by Month', fontsize=12, fontweight='bold', ha='center')
plt.xlabel('Month')
plt.ylabel('Average Change in SWAV')
plt.xticks(ticks=range(12), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.show()

# %%
# @title
import matplotlib.patches as mpatches
from matplotlib.lines import Line2D



# Assuming df_5_day is your DataFrame with 'Date' and 'Change in SWAV' columns
df = df_5_day.copy()

# Ensure 'Date' column is in datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Calculate the absolute value of Change in SWAV
df['Abs_Change_in_SWAV'] = df['Change in SWAV'].abs()

# Calculate the 95th percentile of the absolute values
percentile_95 = np.percentile(df['Abs_Change_in_SWAV'], 95)

# Extract day of the year (1-365 or 1-366 for leap years)
df['DayOfYear'] = df['Date'].dt.dayofyear

# Calculate the average 'Change in SWAV' by each day of the year
daily_avg = df.groupby('DayOfYear')['Change in SWAV'].mean()

# Plot the average 'Change in SWAV' by day of the year
plt.figure(figsize=(14, 8))

# Assign colors based on thresholds
colors = ['lightgreen' if val > percentile_95 else 'lightcoral' if val < -percentile_95 else 'skyblue' for val in daily_avg]

ax = daily_avg.plot(kind='bar', color=colors, width=1.0)

# Add reference lines at the 95th percentile thresholds
plt.axhline(y=percentile_95, color='grey', linestyle='--', linewidth=2)
plt.axhline(y=-percentile_95, color='grey', linestyle='--', linewidth=2)

# Adjust the space above the plot to make room for the titles
plt.subplots_adjust(top=0.78)

# Adding the main title at the top
plt.suptitle('Average SWAV Change by Day of the Year', fontsize=12, fontweight='bold', y=0.83, ha='center')

plt.xlabel('Day of the Year')
plt.ylabel('Average Change in SWAV')
plt.xticks(ticks=[0, 31, 59, 90, 120, 151, 181, 212, 243, 273, 304, 334], labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], rotation=0)

# Create custom legend handles for colors
green_patch = mpatches.Patch(color='lightgreen', label='Above 95th Abs. Percentile')
red_patch = mpatches.Patch(color='lightcoral', label='Below 95th Abs. Percentile')
blue_patch = mpatches.Patch(color='skyblue', label='Within 95th Abs. Percentile')
line = Line2D([0], [0], color='grey', lw=2, linestyle='--', label='95th Abs. Percentile Threshold')

# Show legend with color meanings and reference line
plt.legend(handles=[green_patch, red_patch, blue_patch, line], loc='lower right')

plt.show()

# %% [markdown]
# **Finding:** Out of 12 Days of the Year with Average Change in SWAV Above the 95th Absolute Percentile Threshold, 11 Occur Between 24 Dec and 8 Jan

# %%
# @title
# Calculate the number of days above and below the 0.04 threshold
days_above = len(daily_avg[daily_avg > 0.03598175347244864])
days_below = len(daily_avg[daily_avg < -0.03598175347244864])

# Print the results
print(f"Number of days above/below 95th Abs. Percentile Threshold  : {days_above + days_below} ")

# Filter the data for the festive period (22 Dec to 5 Jan)
festive_period = daily_avg[(daily_avg.index >= 356) | (daily_avg.index <= 8)]

# Calculate the number of days above and below the 0.04 threshold in the festive period
days_above_festive = len(festive_period[festive_period > 0.03598175347244864])
days_below_festive = len(festive_period[festive_period < -0.03598175347244864])

# Print the results
print(f"Number of days between 24 dec and 8 Jan above 95th Abs. Percentile Threshold : {days_above_festive + days_below_festive}")
# Out:
# Number of days above/below 95th Abs. Percentile Threshold  : 25
# Number of days between 24 dec and 8 Jan above 95th Abs. Percentile Threshold : 6

# %%
# @title
# Assuming df_5_day is your DataFrame with 'Date' and 'Change in SWAV' columns
df = df_5_day.copy()

# Ensure 'Date' column is in datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Calculate the absolute value of Change in SWAV
df['Abs_Change_in_SWAV'] = df['Change in SWAV'].abs()

# Calculate the 95th percentile of the absolute values
percentile_95 = np.percentile(df['Abs_Change_in_SWAV'], 95)

# Extract day of the year (1-365 or 1-366 for leap years)
df['DayOfYear'] = df['Date'].dt.dayofyear

# Calculate the average 'Change in SWAV' by each day of the year
daily_avg = df.groupby('DayOfYear')['Change in SWAV'].mean()

# Plot the average 'Change in SWAV' by day of the year
plt.figure(figsize=(14, 8))

# Assign colors based on whether the day is in the festive period (22 Dec to 8 Jan) or not
colors = ['gold' if (day >= 358 or day <= 8) else 'skyblue' for day in daily_avg.index]

ax = daily_avg.plot(kind='bar', color=colors, width=1.0)

# Add reference lines at the 95th absolute percentile thresholds
plt.axhline(y=percentile_95, color='grey', linestyle='--', linewidth=2, label='95th Abs. Percentile Threshold')
plt.axhline(y=-percentile_95, color='grey', linestyle='--', linewidth=2)

# Adjust the space above the plot to make room for the titles
plt.subplots_adjust(top=0.78)

# Adding the main title at the top
plt.suptitle('Average SWAV Change by Day of the Year', fontsize=12, fontweight='bold', y=0.83, ha='center')

plt.xlabel('Day of the Year')
plt.ylabel('Average Change in SWAV')
plt.xticks(ticks=[0, 31, 59, 90, 120, 151, 181, 212, 243, 273, 304, 334], labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], rotation=0)

# # Annotations for the festive period
# plt.annotate('Start of Festive Period: 24 Dec', xy=(356, daily_avg[358]),
#              xytext=(300, daily_avg[358]),
#              arrowprops=dict(facecolor='black', arrowstyle="-", lw=1.5),
#              bbox=dict(boxstyle="round,pad=0.3", edgecolor='black', facecolor='lightyellow'),
#              fontsize=10, ha='center')

# plt.annotate('End of Festive Period: 8 Jan', xy=(7, daily_avg[8]),
#              xytext=(50, daily_avg[8]),
#              arrowprops=dict(facecolor='black', arrowstyle="-", lw=1.5),
#              bbox=dict(boxstyle="round,pad=0.3", edgecolor='black', facecolor='lightyellow'),
#              fontsize=10, ha='center')

# Show legend on the right side
plt.legend(loc='lower right')

plt.show()

# %% [markdown]
# # **Festivity Adjustment: Control for festivity**
#
# Given the big positive changes in SWAV at the end of December, driven by festive music, and the sharp decline at the early January, a dummy variable was introduced to account for these dates.
#
# This adjustment makes sure that the significant festive effects of December and January are properly controlled for in the analysis, preventing them from unduly influencing the observed relationships:
#
# *   The ***negative relationship*** between SWAV changes and FTSE 100 returns remains significant, indicating a consistent pattern outside of these months.
#
# *   The ***positive relationship*** with FTSE Small Cap returns becomes evident, highlighting a potential link between sentiment and smaller, riskier stocks.

# %%
# @title
# Initialize an empty list to store results
results = []
model_summaries = []  # Store model summaries to print later

indices = ['FTSE100', 'FTSE250', 'FTSESmallCap']
days_list = [5]

for days in days_list:
    result_row = [days]  # Start the row with the number of days
    for index in indices:
        df = globals()[f'df_{days}_day']  # Dynamically access each DataFrame

        # Ensure 'Date' column is in datetime format
        df['Date'] = pd.to_datetime(df['Date'])

        # Extract the month and day from the 'Date' column
        df['Month'] = df['Date'].dt.month
        df['Day'] = df['Date'].dt.day

        # Create a festive season dummy variable for December 25th to January 5th
        df['Festive_Season'] = (
            ((df['Month'] == 12) & (df['Day'] >= 24)) |
            ((df['Month'] == 1) & (df['Day'] <= 8))
        ).astype(int)

        # Define the dependent variable
        y = df[f'% {index} Change']

        # Define the independent variables, including Festive_Season
        X = df[['Change in SWAV',
                'ADS_Change',
                'EPU_Change',
                f'Previous % {index} Change',
                '% MSCI Change',
                'Vix Close',
                'Rolling_Avg_Change_in_DCC',
                'Festive_Season']]  # Add Festive_Season here

        # Convert all columns to numeric, coercing errors to NaN
        X = X.apply(pd.to_numeric, errors='coerce')
        y = pd.to_numeric(y, errors='coerce')

        # Drop rows with any NaN values
        X = X.dropna()
        y = y.loc[X.index]  # Ensure 'y' aligns with 'X' after dropping NaNs

        # Ensure that both X and y are aligned and are purely numeric
        if X.shape[0] > 0 and y.shape[0] > 0:  # Proceed only if there's valid data
            # Add a constant term to the model
            X = sm.add_constant(X)

            # Fit the model
            model = sm.OLS(y, X).fit()

            # Extract the coefficient and p-value for 'Change in SWAV'
            coef = round(model.params['Change in SWAV'], 2)
            p_value = round(model.pvalues['Change in SWAV'], 5)

            # Store the coefficient and p-value as a tuple
            result_row.append((coef, p_value))

            # Store the model summary to print later if significant
            if p_value < 0.1:
                model_summaries.append((index, days, model.summary()))

        else:
            result_row.append((None, None))  # Store None for both if no valid data

    # Append the result row for this combination of days
    results.append(result_row)

# Define column names dynamically, ensuring "Days" is the first column
columns = ['Business Days']
for index in indices:
    columns.extend([f'SWAV Change on {index} Change'])

# Convert the results list to a DataFrame, extracting only the coefficients
results_df = pd.DataFrame([[row[0]] + [r[0] if isinstance(r, tuple) else None for r in row[1:]] for row in results], columns=columns)

# Define a function to apply the styling based on significance
def color_rows(row, original_results):
    colors = []
    for i in range(1, len(row)):  # Skip Days, then iterate through Coefs
        # Safely access the original tuple
        item = original_results[row.name][i]
        if isinstance(item, tuple):
            coef, p_value = item
            if coef is not None and p_value < 0.1:  # Only color if p-value < 0.1 (significant)
                if coef > 0:
                    colors.append('background-color: lightgreen')
                elif coef < 0:
                    colors.append('background-color: lightpink')
                else:
                    colors.append('')
            else:
                colors.append('')  # No color for non-significant or None
        else:
            colors.append('')  # No color if item is not a tuple
    return [''] * 1 + colors  # No coloring for Days

# Apply the function to each row of the DataFrame, passing the original results
styled_df = results_df.style.apply(color_rows, axis=1, original_results=results)

# Display the styled DataFrame (in Jupyter or similar environments)
box_message = (
    "--------------------------------------------\n"
    "| Coefficients of 'Change in SWAV' by index |\n"
    "|                                           |\n"
    "| Light green: Significant positive (10%)   |\n"
    "| Light pink: Significant negative (10%)    |\n"
    "--------------------------------------------\n"
)

print(box_message)
display(styled_df)
# Out:
# --------------------------------------------
# | Coefficients of 'Change in SWAV' by index |
# |                                           |
# | Light green: Significant positive (10%)   |
# | Light pink: Significant negative (10%)    |
# --------------------------------------------
# /usr/local/lib/python3.10/dist-packages/statsmodels/regression/linear_model.py:1967: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# <style type="text/css">
# #T_47102_row0_col3 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_47102" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47102_level0_col0" class="col_heading level0 col0" >Business Days</th>
#       <th id="T_47102_level0_col1" class="col_heading level0 col1" >SWAV Change on FTSE100 Change</th>
#       <th id="T_47102_level0_col2" class="col_heading level0 col2" >SWAV Change on FTSE250 Change</th>
#       <th id="T_47102_level0_col3" class="col_heading level0 col3" >SWAV Change on FTSESmallCap Change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47102_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_47102_row0_col0" class="data row0 col0" >5</td>
#       <td id="T_47102_row0_col1" class="data row0 col1" >-4.950000</td>
#       <td id="T_47102_row0_col2" class="data row0 col2" >-0.170000</td>
#       <td id="T_47102_row0_col3" class="data row0 col3" >5.600000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # **Additional Analysis**

# %% [markdown]
# # **Adding Controls: Stringency Index**
#
# To account for pandemic-related dynamics, the COVID-19 stringency index and an interaction term between stringency and SWAV changes were added as controls.
#
# Even with these adjustments, the previous findings remain.
#
# This suggests that these relationships may persist even when considering the impact of pandemic-related restrictions in the UK.

# %%
# @title
# Initialize an empty list to store results
results = []

indices = ['FTSE100', 'FTSE250', 'FTSESmallCap']
days_list = [5]

for days in days_list:
    result_row = [days]  # Start the row with the number of days
    for index in indices:
        df = globals()[f'df_{days}_day']  # Dynamically access each DataFrame

        # Ensure 'Date' column is in datetime format
        df.loc[:, 'Date'] = pd.to_datetime(df['Date'])

        # Extract the month and day from the 'Date' column
        df['Month'] = df['Date'].dt.month
        df['Day'] = df['Date'].dt.day

        # Create a festive season dummy variable for December 25th to January 5th
        df['Festive_Season'] = (
            ((df['Month'] == 12) & (df['Day'] >= 24)) |
            ((df['Month'] == 1) & (df['Day'] <= 8))
        ).astype(int)

        # Covid Stringency Interaction Term
        df.loc[:, 'Covid_Stringency*SWAV'] = df['Change in SWAV'] * df['Stringency_Change']

        # Define the dependent variable
        y = df[f'% {index} Change']

        # Define the independent variables
        X = df[['Change in SWAV',
                'ADS_Change',
                'EPU_Change',
                f'Previous % {index} Change',
                '% MSCI Change',
                'Vix Close',
                'Rolling_Avg_Change_in_DCC',
                'Festive_Season',
                'Stringency_Change',
                'Covid_Stringency*SWAV'
                ]]

        # Create dummy variables for the months
        month_dummies = pd.get_dummies(df['Month'], prefix='Month', drop_first=True)

        # Convert boolean dummy variables to integers
        month_dummies = month_dummies.astype(int)

        # Add the month dummies to the independent variables
       # X = pd.concat([X, month_dummies], axis=1)

        # Convert all columns to numeric, coercing errors to NaN
        X = X.apply(pd.to_numeric, errors='coerce')
        y = pd.to_numeric(y, errors='coerce')

        # Drop rows with any NaN values
        X = X.dropna()
        y = y.loc[X.index]  # Ensure 'y' aligns with 'X' after dropping NaNs

        # Ensure that both X and y are aligned and are purely numeric
        if X.shape[0] > 0 and y.shape[0] > 0:  # Proceed only if there's valid data
            # Add a constant term to the model
            X = sm.add_constant(X)

            # Fit the model
            model = sm.OLS(y, X).fit()

            # Extract the coefficient and p-value for 'Change in SWAV'
            coef = round(model.params['Change in SWAV'], 2)
            p_value = round(model.pvalues['Change in SWAV'], 5)

            # Store the coefficient and p-value as a tuple
            result_row.append((coef, p_value))

    # Append the result row for this combination of days
    results.append(result_row)

# Define column names dynamically, ensuring "Days" is the first column
columns = ['Business Days']
for index in indices:
    columns.extend([f'SWAV Change on {index} Change'])

# Convert the results list to a DataFrame, extracting only the coefficients
results_df = pd.DataFrame([[row[0]] + [r[0] if isinstance(r, tuple) else None for r in row[1:]] for row in results], columns=columns)

# Define a function to apply the styling based on significance
def color_rows(row, original_results):
    colors = []
    for i in range(1, len(row)):  # Skip Days, then iterate through Coefs
        # Safely access the original tuple
        item = original_results[row.name][i]
        if isinstance(item, tuple):
            coef, p_value = item
            if coef is not None and p_value < 0.1:  # Only color if p-value < 0.1 (significant)
                if coef > 0:
                    colors.append('background-color: lightgreen')
                elif coef < 0:
                    colors.append('background-color: lightpink')
                else:
                    colors.append('')
            else:
                colors.append('')  # No color for non-significant or None
        else:
            colors.append('')  # No color if item is not a tuple
    return [''] * 1 + colors  # No coloring for Days

# Apply the function to each row of the DataFrame, passing the original results
styled_df = results_df.style.apply(color_rows, axis=1, original_results=results)

# Display the styled DataFrame (in Jupyter or similar environments)
styled_df
# Out:
# <style type="text/css">
# #T_11301_row0_col3 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_11301" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11301_level0_col0" class="col_heading level0 col0" >Business Days</th>
#       <th id="T_11301_level0_col1" class="col_heading level0 col1" >SWAV Change on FTSE100 Change</th>
#       <th id="T_11301_level0_col2" class="col_heading level0 col2" >SWAV Change on FTSE250 Change</th>
#       <th id="T_11301_level0_col3" class="col_heading level0 col3" >SWAV Change on FTSESmallCap Change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11301_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_11301_row0_col0" class="data row0 col0" >5</td>
#       <td id="T_11301_row0_col1" class="data row0 col1" >-4.620000</td>
#       <td id="T_11301_row0_col2" class="data row0 col2" >-0.330000</td>
#       <td id="T_11301_row0_col3" class="data row0 col3" >5.150000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # **Adding Controls: TED Spread**

# %%
# @title
df = globals()[f'df_5_day_TED']  # Dynamically access each DataFrame

df = df.copy()

# Ensure 'Date' column is in datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Plot the TED spread over time
plt.figure(figsize=(14, 8))
plt.plot(df['Date'], df['TED'], color='blue', label='TED Spread', linewidth=2)

high_threshold = df['TED'].quantile(0.90)  # or choose any other appropriate threshold

# Add a reference line for the high threshold
plt.axhline(y=high_threshold, color='red', linestyle='--', linewidth=2, label=f'90% High Threshold ({high_threshold:.2f})')

# Add labels and title
plt.title('TED Spread Over Time with High Threshold', fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('TED Spread', fontsize=14)

# Add a legend
plt.legend(loc='upper left')

# Add grid for better readability
plt.grid(True)

# Display the plot
plt.show()

# %% [markdown]
# # **Adding Controls: TED Spread and Interaction Term**
#
# To account for liquidity risk, the TED spread and an interaction term between TED spread and SWAV changes were added. Despite these adjustments, the previous findings persist, indicating that liquidity factors alone do not fully explain these relationships.

# %%
# @title
from scipy.stats import mstats

# Initialize an empty list to store results
results = []

indices = ['FTSE100', 'FTSE250', 'FTSESmallCap']
days_list = [5]

for days in days_list:
    result_row = [days]  # Start the row with the number of days
    for index in indices:
        df = globals()[f'df_{days}_day_TED']  # Dynamically access each DataFrame

        df = df.copy()

        # Convert the 'Date' column to datetime format
        df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

        # Extract the month and day from the 'Date' column
        df['Month'] = df['Date'].dt.month
        df['Day'] = df['Date'].dt.day

        # Create a festive season dummy variable for December 25th to January 5th
        df.loc[:, 'Festive_Season'] = (
            ((df['Month'] == 12) & (df['Day'] >= 24)) |
            ((df['Month'] == 1) & (df['Day'] <= 8))
        ).astype(int)

        # Covid Stringency Interaction Term
        df.loc[:, 'Covid_Stringency*SWAV'] = df['Change in SWAV'] * df['Stringency_Change']

        # Set the threshold for high TED (e.g., 90th percentile)
        high_ted_threshold = df['TED'].quantile(0.90)

        # Create the TED dummy variable
        df['High_TED'] = (df['TED'] > high_ted_threshold).astype(int)

        # Create the interaction term between High_TED and Change in SWAV
        df['High_TED*SWAV'] = df['High_TED'] * df['Change in SWAV']

        # Define the dependent variable
        y = df[f'% {index} Change']

        # Define the independent variables
        X = df[['Change in SWAV',
                'High_TED',
                'High_TED*SWAV',
                'ADS_Change',
                'EPU_Change',
                f'Previous % {index} Change',
                '% MSCI Change',
                'Vix Close',
                'Rolling_Avg_Change_in_DCC',
                'Festive_Season',
                'Stringency_Change',
                'Covid_Stringency*SWAV'
                ]]

        # Create dummy variables for the months
        month_dummies = pd.get_dummies(df['Month'], prefix='Month', drop_first=True)

        # Convert boolean dummy variables to integers
        month_dummies = month_dummies.astype(int)

        # Add the month dummies to the independent variables
        #X = pd.concat([X, month_dummies], axis=1)

        # Convert all columns to numeric, coercing errors to NaN
        X = X.apply(pd.to_numeric, errors='coerce')
        y = pd.to_numeric(y, errors='coerce')

        # Drop rows with any NaN values
        X = X.dropna()
        y = y.loc[X.index]  # Ensure 'y' aligns with 'X' after dropping NaNs

        # Ensure that both X and y are aligned and are purely numeric
        if X.shape[0] > 0 and y.shape[0] > 0:  # Proceed only if there's valid data
            # Add a constant term to the model
            X = sm.add_constant(X)

            # Fit the model
            model = sm.OLS(y, X).fit()

            # Extract the coefficient and p-value for 'Change in SWAV'
            coef = round(model.params['Change in SWAV'], 2)
            p_value = round(model.pvalues['Change in SWAV'], 5)

            # Store the coefficient and p-value as a tuple
            result_row.append((coef, p_value))

            print(model.summary())

    # Append the result row for this combination of days
    results.append(result_row)

# Define column names dynamically, ensuring "Days" is the first column
columns = ['Business Days']
for index in indices:
    columns.extend([f'SWAV Change on {index} Change'])

# Convert the results list to a DataFrame, extracting only the coefficients
results_df = pd.DataFrame([[row[0]] + [r[0] if isinstance(r, tuple) else None for r in row[1:]] for row in results], columns=columns)

# Define a function to apply the styling based on significance
def color_rows(row, original_results):
    colors = []
    for i in range(1, len(row)):  # Skip Days, then iterate through Coefs
        # Safely access the original tuple
        item = original_results[row.name][i]
        if isinstance(item, tuple):
            coef, p_value = item
            if coef is not None and p_value < 0.1:  # Only color if p-value < 0.1 (significant)
                if coef > 0:
                    colors.append('background-color: lightgreen')
                elif coef < 0:
                    colors.append('background-color: lightpink')
                else:
                    colors.append('')
            else:
                colors.append('')  # No color for non-significant or None
        else:
            colors.append('')  # No color if item is not a tuple
    return [''] * 1 + colors  # No coloring for Days

# Apply the function to each row of the DataFrame, passing the original results
styled_df = results_df.style.apply(color_rows, axis=1, original_results=results)

# Display the styled DataFrame (in Jupyter or similar environments)
styled_df
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       % FTSE100 Change   R-squared:                       0.652
# Model:                            OLS   Adj. R-squared:                  0.636
# Method:                 Least Squares   F-statistic:                     40.83
# Date:                Sat, 07 Sep 2024   Prob (F-statistic):           7.64e-49
# Time:                        11:26:21   Log-Likelihood:                -433.72
# No. Observations:                 252   AIC:                             891.4
# Df Residuals:                     240   BIC:                             933.8
# Df Model:                          11
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         0.0426      0.238      0.179      0.858      -0.427       0.512
# Change in SWAV               -3.2160      4.348     -0.740      0.460     -11.780       5.348
# High_TED                      0.4553      0.331      1.377      0.170      -0.196       1.106
# High_TED*SWAV               -26.2209     25.625     -1.023      0.307     -76.700      24.259
# ADS_Change                    0.1028      0.075      1.369      0.172      -0.045       0.251
# EPU_Change                   -0.0006      0.001     -0.961      0.337      -0.002       0.001
# Previous % FTSE100 Change    -0.0604      0.045     -1.352      0.178      -0.148       0.028
# % MSCI Change                 0.7494      0.041     18.468      0.000       0.669       0.829
# Vix Close                    -0.0132      0.012     -1.066      0.288      -0.038       0.011
# Rolling_Avg_Change_in_DCC  9.803e-15   1.14e-14      0.857      0.392   -1.27e-14    3.23e-14
# Festive_Season                0.3427      0.510      0.673      0.502      -0.661       1.347
# Stringency_Change             0.1277      0.153      0.834      0.405      -0.174       0.429
# Covid_Stringency*SWAV       -11.7500      4.881     -2.407      0.017     -21.365      -2.135
# ==============================================================================
# Omnibus:                       26.531   Durbin-Watson:                   1.955
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              130.173
# Skew:                          -0.014   Prob(JB):                     5.41e-29
# Kurtosis:                       6.521   Cond. No.                     3.19e+20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.03e-35. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       % FTSE250 Change   R-squared:                       0.769
# Model:                            OLS   Adj. R-squared:                  0.759
# Method:                 Least Squares   F-statistic:                     72.75
# Date:                Sat, 07 Sep 2024   Prob (F-statistic):           5.51e-70
# Time:                        11:26:21   Log-Likelihood:                -414.78
# No. Observations:                 252   AIC:                             853.6
# Df Residuals:                     240   BIC:                             895.9
# Df Model:                          11
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         0.1394      0.222      0.629      0.530      -0.297       0.576
# Change in SWAV               -1.5221      4.029     -0.378      0.706      -9.460       6.416
# High_TED                      0.4063      0.305      1.331      0.185      -0.195       1.008
# High_TED*SWAV                 0.6215     23.523      0.026      0.979     -45.717      46.960
# ADS_Change                    0.1047      0.070      1.492      0.137      -0.034       0.243
# EPU_Change                   -0.0005      0.001     -0.775      0.439      -0.002       0.001
# Previous % FTSE250 Change    -0.0461      0.037     -1.247      0.214      -0.119       0.027
# % MSCI Change                 0.8933      0.038     23.762      0.000       0.819       0.967
# Vix Close                    -0.0154      0.011     -1.342      0.181      -0.038       0.007
# Rolling_Avg_Change_in_DCC -6.544e-16   1.31e-14     -0.050      0.960   -2.66e-14    2.52e-14
# Festive_Season                0.4584      0.473      0.969      0.334      -0.474       1.391
# Stringency_Change            -0.1542      0.143     -1.081      0.281      -0.435       0.127
# Covid_Stringency*SWAV         0.2510      4.464      0.056      0.955      -8.543       9.045
# ==============================================================================
# Omnibus:                       14.235   Durbin-Watson:                   2.236
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               37.050
# Skew:                          -0.055   Prob(JB):                     9.01e-09
# Kurtosis:                       4.875   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     % FTSESmallCap Change   R-squared:                       0.794
# Model:                               OLS   Adj. R-squared:                  0.784
# Method:                    Least Squares   F-statistic:                     83.91
# Date:                   Sat, 07 Sep 2024   Prob (F-statistic):           9.80e-76
# Time:                           11:26:21   Log-Likelihood:                -355.36
# No. Observations:                    252   AIC:                             734.7
# Df Residuals:                        240   BIC:                             777.1
# Df Model:                             11
# Covariance Type:               nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                             -0.0892      0.175     -0.511      0.610      -0.433       0.255
# Change in SWAV                     4.8483      3.195      1.517      0.130      -1.446      11.142
# High_TED                           0.1945      0.242      0.805      0.422      -0.282       0.671
# High_TED*SWAV                     17.2613     18.561      0.930      0.353     -19.303      53.825
# ADS_Change                         0.0366      0.055      0.661      0.509      -0.072       0.146
# EPU_Change                        -0.0005      0.000     -1.055      0.293      -0.001       0.000
# Previous % FTSESmallCap Change     0.0938      0.037      2.545      0.012       0.021       0.166
# % MSCI Change                      0.7450      0.030     25.101      0.000       0.687       0.803
# Vix Close                          0.0012      0.009      0.128      0.898      -0.017       0.019
# Rolling_Avg_Change_in_DCC       6.838e-15   8.29e-15      0.825      0.410    -9.5e-15    2.32e-14
# Festive_Season                     0.6954      0.373      1.863      0.064      -0.040       1.431
# Stringency_Change                 -0.3516      0.116     -3.022      0.003      -0.581      -0.122
# Covid_Stringency*SWAV              1.6883      3.527      0.479      0.633      -5.260       8.637
# ==============================================================================
# Omnibus:                       19.834   Durbin-Watson:                   2.195
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               54.939
# Skew:                           0.256   Prob(JB):                     1.18e-12
# Kurtosis:                       5.229   Cond. No.                     2.24e+20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.02e-34. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# /usr/local/lib/python3.10/dist-packages/statsmodels/regression/linear_model.py:1967: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# <style type="text/css">
# </style>
# <table id="T_da0df" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_da0df_level0_col0" class="col_heading level0 col0" >Business Days</th>
#       <th id="T_da0df_level0_col1" class="col_heading level0 col1" >SWAV Change on FTSE100 Change</th>
#       <th id="T_da0df_level0_col2" class="col_heading level0 col2" >SWAV Change on FTSE250 Change</th>
#       <th id="T_da0df_level0_col3" class="col_heading level0 col3" >SWAV Change on FTSESmallCap Change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da0df_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_da0df_row0_col0" class="data row0 col0" >5</td>
#       <td id="T_da0df_row0_col1" class="data row0 col1" >-3.220000</td>
#       <td id="T_da0df_row0_col2" class="data row0 col2" >-1.520000</td>
#       <td id="T_da0df_row0_col3" class="data row0 col3" >4.850000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # **Multicollinearity Check**
#
# A Variance Inflation Factor (VIF) analysis confirms that multicollinearity is not an issue in the regression models, supporting the reliability of the results.

# %%
df_5_day_TED = pd.read_csv(url_5_day_TED)
df_5_day_TED.loc[:, 'Stringency_Change*SWAV'] = df_5_day_TED['Change in SWAV'] * df_5_day_TED['Stringency_Change']
df_5_day_TED['High_TED'] = (df['TED'] > high_ted_threshold).astype(int)
df_5_day_TED.loc[:, 'High_TED*SWAV'] = df_5_day_TED['Change in SWAV'] * df_5_day_TED['High_TED']

# Define the independent variables
X = df_5_day_TED[['Change in SWAV',
                  'ADS_Change',
                  'EPU_Change',
                  f'Previous % {index} Change',
                  '% MSCI Change',
                  'Vix Close',
                  'Rolling_Avg_Change_in_DCC',
                  'Stringency_Change',
                  'Stringency_Change*SWAV',
                  'High_TED',
                  'High_TED*SWAV'
                  ]]

# Add a constant to the independent variables matrix (for intercept)
X = sm.add_constant(X)

# Calculate VIF for each variable
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# Style the VIF DataFrame
styled_vif = vif_data.style.set_caption("Variance Inflation Factors (VIF)")
styled_vif = styled_vif.set_table_styles([
    {'selector': 'caption', 'props': [('font-size', '16px'), ('font-weight', 'bold'), ('text-align', 'center')]},
    {'selector': 'th', 'props': [('background-color', '#f0f0f0'), ('font-weight', 'bold')]},
    {'selector': 'td', 'props': [('border', '1px solid #ddd'), ('padding', '8px')]},
    {'selector': 'tr:nth-child(even)', 'props': [('background-color', '#f9f9f9')]},
    {'selector': 'tr:hover', 'props': [('background-color', '#f5f5f5')]}
])

# Display the styled VIF DataFrame
display(styled_vif)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# <style type="text/css">
# #T_79403 caption {
#   font-size: 16px;
#   font-weight: bold;
#   text-align: center;
# }
# #T_79403 th {
#   background-color: #f0f0f0;
#   font-weight: bold;
# }
# #T_79403 td {
#   border: 1px solid #ddd;
#   padding: 8px;
# }
# #T_79403 tr:nth-child(even) {
#   background-color: #f9f9f9;
# }
# #T_79403 tr:hover {
#   background-color: #f5f5f5;
# }
# </style>
# <table id="T_79403" class="dataframe">
#   <caption>Variance Inflation Factors (VIF)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_79403_level0_col0" class="col_heading level0 col0" >feature</th>
#       <th id="T_79403_level0_col1" class="col_heading level0 col1" >VIF</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79403_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_79403_row0_col0" class="data row0 col0" >const</td>
#       <td id="T_79403_row0_col1" class="data row0 col1" >7.413831</td>
#     </tr>
#     <tr>
#       <th id="T_79403_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_79403_row1_col0" class="data row1 col0" >Change in SWAV</td>
#       <td id="T_79403_row1_col1" class="data row1 col1" >1.084257</td>
#     </tr>
#     <tr>
#       <th id="T_79403_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_79403_row2_col0" class="data row2 col0" >ADS_Change</td>
#       <td id="T_79403_row2_col1" class="data row2 col1" >1.305459</td>
#     </tr>
#     <tr>
#       <th id="T_79403_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_79403_row3_col0" class="data row3 col0" >EPU_Change</td>
#       <td id="T_79403_row3_col1" class="data row3 col1" >1.067862</td>
#     </tr>
#     <tr>
#       <th id="T_79403_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_79403_row4_col0" class="data row4 col0" >Previous % FTSESmallCap Change</td>
#       <td id="T_79403_row4_col1" class="data row4 col1" >1.550652</td>
#     </tr>
#     <tr>
#       <th id="T_79403_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_79403_row5_col0" class="data row5 col0" >% MSCI Change</td>
#       <td id="T_79403_row5_col1" class="data row5 col1" >1.298054</td>
#     </tr>
#     <tr>
#       <th id="T_79403_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_79403_row6_col0" class="data row6 col0" >Vix Close</td>
#       <td id="T_79403_row6_col1" class="data row6 col1" >1.411440</td>
#     </tr>
#     <tr>
#       <th id="T_79403_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_79403_row7_col0" class="data row7 col0" >Rolling_Avg_Change_in_DCC</td>
#       <td id="T_79403_row7_col1" class="data row7 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_79403_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_79403_row8_col0" class="data row8 col0" >Stringency_Change</td>
#       <td id="T_79403_row8_col1" class="data row8 col1" >1.987455</td>
#     </tr>
#     <tr>
#       <th id="T_79403_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_79403_row9_col0" class="data row9 col0" >Stringency_Change*SWAV</td>
#       <td id="T_79403_row9_col1" class="data row9 col1" >1.702792</td>
#     </tr>
#     <tr>
#       <th id="T_79403_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_79403_row10_col0" class="data row10 col0" >High_TED</td>
#       <td id="T_79403_row10_col1" class="data row10 col1" >1.128950</td>
#     </tr>
#     <tr>
#       <th id="T_79403_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_79403_row11_col0" class="data row11 col0" >High_TED*SWAV</td>
#       <td id="T_79403_row11_col1" class="data row11 col1" >1.526163</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # **Assessing Robustness Using Different Timeframes**
# The analysis shows varying robustness in the relationship between SWAV changes and UK market returns:
#
# *   FTSE 100: Significant negative relationships in the 3-day and 5-day windows
# suggest a short-to-medium term impact, with no immediate effect seen in the 1-day or longer-term 10-day windows.
#
# *   FTSE 250: A significant positive relationship appears only in the 10-day window, indicating a gradual influence of sentiment on this index.
#
# *   FTSE Small Cap: Consistent positive relationships across all windows highlight a strong, robust response to sentiment changes in smaller, riskier stocks.
#
# These results suggest that sentiment impacts market returns differently depending on the index and timeframe, with FTSE Small Cap showing the most consistent response.

# %%
# @title
# Initialize an empty list to store results
results = []

indices = ['FTSE100', 'FTSE250', 'FTSESmallCap']
days_list = [1,3,5,10]

for days in days_list:
    result_row = [days]  # Start the row with the number of days
    for index in indices:
        df = globals()[f'df_{days}_day_TED']  # Dynamically access each DataFrame

        df = df.copy()

        # Convert the 'Date' column to datetime format
        df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

        # Extract the month and day from the 'Date' column
        df['Month'] = df['Date'].dt.month
        df['Day'] = df['Date'].dt.day

        # Create a festive season dummy variable for December 25th to January 5th
        df.loc[:, 'Festive_Season'] = (
            ((df['Month'] == 12) & (df['Day'] >= 24)) |
            ((df['Month'] == 1) & (df['Day'] <= 8))
        ).astype(int)

        # Covid Stringency Interaction Term
        df.loc[:, 'Covid_Stringency*SWAV'] = df['Change in SWAV'] * df['Stringency_Change']

        # Set the threshold for high TED (e.g., 90th percentile)
        high_ted_threshold = df['TED'].quantile(0.90)

        # Create the TED dummy variable
        df['High_TED'] = (df['TED'] > high_ted_threshold).astype(int)

        # Create the interaction term between High_TED and Change in SWAV
        df['High_TED*SWAV'] = df['High_TED'] * df['Change in SWAV']

        # Define the dependent variable
        y = df[f'% {index} Change']

        # Define the independent variables
        X = df[['Change in SWAV',
                'ADS_Change',
                'EPU_Change',
                f'Previous % {index} Change',
                '% MSCI Change',
                'Vix Close',
                'Rolling_Avg_Change_in_DCC',
                'Festive_Season',
                'Stringency_Change',
                'Covid_Stringency*SWAV',
                'High_TED',
                'High_TED*SWAV',
                ]]

        # Convert all columns to numeric, coercing errors to NaN
        X = X.apply(pd.to_numeric, errors='coerce')
        y = pd.to_numeric(y, errors='coerce')

        # Drop rows with any NaN values
        X = X.dropna()
        y = y.loc[X.index]  # Ensure 'y' aligns with 'X' after dropping NaNs

        # Ensure that both X and y are aligned and are purely numeric
        if X.shape[0] > 0 and y.shape[0] > 0:  # Proceed only if there's valid data
            # Add a constant term to the model
            X = sm.add_constant(X)

            # Fit the model
            model = sm.OLS(y, X).fit()

            # Extract the coefficient and p-value for 'Change in SWAV'
            coef = round(model.params['Change in SWAV'], 2)
            p_value = round(model.pvalues['Change in SWAV'], 5)

            # Store the coefficient and p-value as a tuple
            result_row.append((coef, p_value))

    # Append the result row for this combination of days
    results.append(result_row)

# Define column names dynamically, ensuring "Days" is the first column
columns = ['Business Days']
for index in indices:
    columns.extend([f'SWAV Change on {index} Change'])

# Convert the results list to a DataFrame, extracting only the coefficients
results_df = pd.DataFrame([[row[0]] + [r[0] if isinstance(r, tuple) else None for r in row[1:]] for row in results], columns=columns)

# Define a function to apply the styling based on significance
def color_rows(row, original_results):
    colors = []
    for i in range(1, len(row)):  # Skip Days, then iterate through Coefs
        # Safely access the original tuple
        item = original_results[row.name][i]
        if isinstance(item, tuple):
            coef, p_value = item
            if coef is not None and p_value < 0.1:  # Only color if p-value < 0.1 (significant)
                if coef > 0:
                    colors.append('background-color: lightgreen')
                elif coef < 0:
                    colors.append('background-color: lightpink')
                else:
                    colors.append('')
            else:
                colors.append('')  # No color for non-significant or None
        else:
            colors.append('')  # No color if item is not a tuple
    return [''] * 1 + colors  # No coloring for Days

# Apply the function to each row of the DataFrame, passing the original results
styled_df = results_df.style.apply(color_rows, axis=1, original_results=results)

# Display the styled DataFrame (in Jupyter or similar environments)
styled_df
# Out:
# <style type="text/css">
# #T_6f434_row3_col2, #T_6f434_row3_col3 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6f434" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f434_level0_col0" class="col_heading level0 col0" >Business Days</th>
#       <th id="T_6f434_level0_col1" class="col_heading level0 col1" >SWAV Change on FTSE100 Change</th>
#       <th id="T_6f434_level0_col2" class="col_heading level0 col2" >SWAV Change on FTSE250 Change</th>
#       <th id="T_6f434_level0_col3" class="col_heading level0 col3" >SWAV Change on FTSESmallCap Change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f434_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6f434_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_6f434_row0_col1" class="data row0 col1" >-3.220000</td>
#       <td id="T_6f434_row0_col2" class="data row0 col2" >-1.520000</td>
#       <td id="T_6f434_row0_col3" class="data row0 col3" >4.850000</td>
#     </tr>
#     <tr>
#       <th id="T_6f434_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6f434_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_6f434_row1_col1" class="data row1 col1" >-5.100000</td>
#       <td id="T_6f434_row1_col2" class="data row1 col2" >-4.820000</td>
#       <td id="T_6f434_row1_col3" class="data row1 col3" >4.360000</td>
#     </tr>
#     <tr>
#       <th id="T_6f434_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6f434_row2_col0" class="data row2 col0" >5</td>
#       <td id="T_6f434_row2_col1" class="data row2 col1" >-3.220000</td>
#       <td id="T_6f434_row2_col2" class="data row2 col2" >-1.520000</td>
#       <td id="T_6f434_row2_col3" class="data row2 col3" >4.850000</td>
#     </tr>
#     <tr>
#       <th id="T_6f434_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6f434_row3_col0" class="data row3 col0" >10</td>
#       <td id="T_6f434_row3_col1" class="data row3 col1" >3.320000</td>
#       <td id="T_6f434_row3_col2" class="data row3 col2" >8.780000</td>
#       <td id="T_6f434_row3_col3" class="data row3 col3" >6.700000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # **Lagged Analysis: Delayed Market Reactions**
#
# A lagged regression shows a significant positive relationship for the FTSE 100 in the 5-day and 10-day windows. This suggests that initial negative market reactions to sentiment changes might shift over time, possibly indicating a delayed correction consistent with risk-off behavior.
#
# No significant effects were found for other indices, hinting that this pattern may be specific to the FTSE 100.

# %%
# @title
# Initialize an empty list to store results
results = []

indices = ['FTSE100', 'FTSE250', 'FTSESmallCap']
days_list = [1,3,5,10,20]

for days in days_list:
    result_row = [days]  # Start the row with the number of days
    for index in indices:
        df = globals()[f'df_{days}_day_TED']  # Dynamically access each DataFrame

        # Convert the 'Date' column to datetime format
        df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

        # Extract the month and day from the 'Date' column
        df['Month'] = df['Date'].dt.month
        df['Day'] = df['Date'].dt.day

        # Create a festive season dummy variable for December 25th to January 5th
        df.loc[:, 'Festive_Season'] = (
            ((df['Month'] == 12) & (df['Day'] >= 24)) |
            ((df['Month'] == 1) & (df['Day'] <= 8))
        ).astype(int)

        # Covid Stringency Interaction Term
        df.loc[:, 'Covid_Stringency*SWAV'] = df['Change in SWAV'] * df['Stringency_Change']

        # Set the threshold for high TED (e.g., 90th percentile)
        high_ted_threshold = df['TED'].quantile(0.90)

        # Create the TED dummy variable
        df['High_TED'] = (df['TED'] > high_ted_threshold).astype(int)

        # Create the interaction term between High_TED and Change in SWAV
        df['High_TED*SWAV'] = df['High_TED'] * df['Change in SWAV']

        # Define the dependent variable
        y = df[f'Next % {index} Change']

        # Define the independent variables
        X = df[['Change in SWAV',
                'ADS_Change',
                'EPU_Change',
                f'% {index} Change',
                'Next % MSCI Change',
                'Vix Close',
                'Rolling_Avg_Change_in_DCC',
                'Festive_Season',
                'Stringency_Change',
                'Covid_Stringency*SWAV',
                'High_TED',
                'High_TED*SWAV',
                ]]

        # Convert all columns to numeric, coercing errors to NaN
        X = X.apply(pd.to_numeric, errors='coerce')
        y = pd.to_numeric(y, errors='coerce')

        # Drop rows with any NaN values
        X = X.dropna()
        y = y.loc[X.index]  # Ensure 'y' aligns with 'X' after dropping NaNs

        # Ensure that both X and y are aligned and are purely numeric
        if X.shape[0] > 0 and y.shape[0] > 0:  # Proceed only if there's valid data
            # Add a constant term to the model
            X = sm.add_constant(X)

            # Fit the model
            model = sm.OLS(y, X).fit()

            # Extract the coefficient and p-value for 'Change in SWAV'
            coef = round(model.params['Change in SWAV'], 2)
            p_value = round(model.pvalues['Change in SWAV'], 5)

            # Store the coefficient and p-value as a tuple
            result_row.append((coef, p_value))

    # Append the result row for this combination of days
    results.append(result_row)

# Define column names dynamically, ensuring "Days" is the first column
columns = ['Business Days']
for index in indices:
    columns.extend([f'SWAV Change on Next Period {index} Change'])

# Convert the results list to a DataFrame, extracting only the coefficients
results_df = pd.DataFrame([[row[0]] + [r[0] if isinstance(r, tuple) else None for r in row[1:]] for row in results], columns=columns)

# Define a function to apply the styling based on significance
def color_rows(row, original_results):
    colors = []
    for i in range(1, len(row)):  # Skip Days, then iterate through Coefs
        # Safely access the original tuple
        item = original_results[row.name][i]
        if isinstance(item, tuple):
            coef, p_value = item
            if coef is not None and p_value < 0.1:  # Only color if p-value < 0.1 (significant)
                if coef > 0:
                    colors.append('background-color: lightgreen')
                elif coef < 0:
                    colors.append('background-color: lightpink')
                else:
                    colors.append('')
            else:
                colors.append('')  # No color for non-significant or None
        else:
            colors.append('')  # No color if item is not a tuple
    return [''] * 1 + colors  # No coloring for Days

# Apply the function to each row of the DataFrame, passing the original results
styled_df = results_df.style.apply(color_rows, axis=1, original_results=results)

# Display the styled DataFrame (in Jupyter or similar environments)
styled_df
# Out:
# <style type="text/css">
# #T_f87ff_row0_col1, #T_f87ff_row0_col2, #T_f87ff_row2_col1, #T_f87ff_row2_col2, #T_f87ff_row3_col1, #T_f87ff_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f87ff" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f87ff_level0_col0" class="col_heading level0 col0" >Business Days</th>
#       <th id="T_f87ff_level0_col1" class="col_heading level0 col1" >SWAV Change on Next Period FTSE100 Change</th>
#       <th id="T_f87ff_level0_col2" class="col_heading level0 col2" >SWAV Change on Next Period FTSE250 Change</th>
#       <th id="T_f87ff_level0_col3" class="col_heading level0 col3" >SWAV Change on Next Period FTSESmallCap Change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f87ff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f87ff_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_f87ff_row0_col1" class="data row0 col1" >8.740000</td>
#       <td id="T_f87ff_row0_col2" class="data row0 col2" >10.100000</td>
#       <td id="T_f87ff_row0_col3" class="data row0 col3" >2.850000</td>
#     </tr>
#     <tr>
#       <th id="T_f87ff_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f87ff_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_f87ff_row1_col1" class="data row1 col1" >4.400000</td>
#       <td id="T_f87ff_row1_col2" class="data row1 col2" >1.840000</td>
#       <td id="T_f87ff_row1_col3" class="data row1 col3" >-0.160000</td>
#     </tr>
#     <tr>
#       <th id="T_f87ff_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f87ff_row2_col0" class="data row2 col0" >5</td>
#       <td id="T_f87ff_row2_col1" class="data row2 col1" >8.740000</td>
#       <td id="T_f87ff_row2_col2" class="data row2 col2" >10.100000</td>
#       <td id="T_f87ff_row2_col3" class="data row2 col3" >2.850000</td>
#     </tr>
#     <tr>
#       <th id="T_f87ff_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f87ff_row3_col0" class="data row3 col0" >10</td>
#       <td id="T_f87ff_row3_col1" class="data row3 col1" >12.480000</td>
#       <td id="T_f87ff_row3_col2" class="data row3 col2" >-3.830000</td>
#       <td id="T_f87ff_row3_col3" class="data row3 col3" >0.660000</td>
#     </tr>
#     <tr>
#       <th id="T_f87ff_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f87ff_row4_col0" class="data row4 col0" >20</td>
#       <td id="T_f87ff_row4_col1" class="data row4 col1" >13.110000</td>
#       <td id="T_f87ff_row4_col2" class="data row4 col2" >-0.260000</td>
#       <td id="T_f87ff_row4_col3" class="data row4 col3" >-0.710000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # **Conclusion: Sentiment, Risk, and Market Dynamics**
#
# The study finds a negative relationship between SWAV changes and FTSE 100 returns, suggesting the FTSE 100 might act as a safe asset in the UK, possibly reflecting risk-off behavior.
# The positive relationship with FTSE Small Cap returns could support this, but further research is needed to fully understand these dynamics.
